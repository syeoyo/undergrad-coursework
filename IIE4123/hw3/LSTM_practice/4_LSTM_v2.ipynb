# %% [markdown]
# #### 1) 데이터 불러오기

# %%
import torch
import warnings
import time
import random
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm
import matplotlib.pyplot   as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import torch
import torch.nn                     as nn
import torch.nn.functional          as F
from   torch.utils.data             import Dataset,DataLoader


# 시드(seed) 고정
random_seed = 42
torch.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
warnings.filterwarnings(action='ignore')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
# 데이터 파일 경로 설정
df = pd.read_csv('C:/Users/symply_jina/Desktop/seohyun/IIE4123/hw3/LSTM_practice/electricity.csv')

# %%
# 하이퍼 파라미터 설정
class Parameters():
    def __init__(self):
        self.description = 'LSTM 모델을 이용한 시계열 예측'
        # 입력 시퀀스 길이 - look-back
        self.Lag         = 30
        # 예측 시퀀스 길이
        self.Horizon     = 7

        # 에포크 수
        self.epochs        = 500
        # 배치 크기
        self.batch_size    = 16
        # 학습률
        self.learning_rate = 1e-4 # 0.0001
        # 훈련된 모델 경로
        self.model_name    = 'LSTM'
        # 파일명
        self.filename              = './LSTM_practice/electricity.csv'
        # 대상 시계열 이름
        self.targetSeries          = 'OT'
        # 훈련 세트 비율
        self.TrainingSetPercentage = 0.8
        # 스케일링 {'Standard', 'MinMax', 'Robust'}
        self.Scaling               = 'Standard'


args = Parameters()

# %%
df
# Out:
#                       date    supplyT    returnT    volume     energy  \
# 0      2019-08-21 05:00:00  62.552500  41.200000  153128.4  2762320.0
# 1      2019-08-21 06:00:00  62.297143  43.724286  153128.9  2762340.0
# 2      2019-08-21 07:00:00  62.051429  47.042857  153129.4  2762340.0
# 3      2019-08-21 08:00:00  61.840000  45.663750  153129.9  2762360.0
# 4      2019-08-21 09:00:00  62.202857  43.570000  153130.6  2762370.0
# ...                    ...        ...        ...       ...        ...
# 21492  2022-02-01 17:00:00  76.191818  40.070000  173871.3  3384290.0
# 21493  2022-02-01 18:00:00  76.115000  39.591000  173872.5  3384340.0
# 21494  2022-02-01 19:00:00  75.956364  38.787273  173873.7  3384390.0
# 21495  2022-02-01 20:00:00  76.007273  38.352727  173875.0  3384450.0
# 21496  2022-02-01 21:00:00  76.064000  38.667000  173876.3  3384500.0
#
#            flow  Frederikshavn Temperature [2 m elevation corrected]  \
# 0      0.678000                                          12.157285
# 1      0.589714                                          12.517284
# 2      0.510857                                          12.897284
# 3      0.429000                                          13.387284
# 4      0.812571                                          13.897284
# ...         ...                                                ...
# 21492  1.217455                                           5.197285
# 21493  1.279200                                           4.497285
# 21494  1.217455                                           3.987285
# 21495  1.208727                                           3.637285
# 21496  1.293600                                           3.467285
#
#               OT
# 0      16.775000
# 1      12.071429
# 2      10.028571
# 3       8.837500
# 4      20.014286
# ...          ...
# 21492  50.790909
# 21493  53.970000
# 21494  52.209091
# 21495  52.518182
# 21496  55.820000
#
# [21497 rows x 8 columns]

# %% [markdown]
# ### Univariate Forecasting

# %%
# 날짜로 인식하게 수정 후 데이터프레임으로 변환
df['date'] = df['date'].astype('datetime64[ns]')
df.set_index('date', inplace=True)
df = pd.DataFrame( df[ [ args.targetSeries ] ] )
df
# Out:
#                             OT
# date
# 2019-08-21 05:00:00  16.775000
# 2019-08-21 06:00:00  12.071429
# 2019-08-21 07:00:00  10.028571
# 2019-08-21 08:00:00   8.837500
# 2019-08-21 09:00:00  20.014286
# ...                        ...
# 2022-02-01 17:00:00  50.790909
# 2022-02-01 18:00:00  53.970000
# 2022-02-01 19:00:00  52.209091
# 2022-02-01 20:00:00  52.518182
# 2022-02-01 21:00:00  55.820000
#
# [21497 rows x 1 columns]

# %%
# 80% 훈련 나머지 테스트
idx = int( df.shape[0] * args.TrainingSetPercentage )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
# 학습 및 테스트 데이터 시각화
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train.plot(ax=ax, color='tab:blue' )
df_test.plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], fontsize = 14)
plt.ylabel(args.targetSeries, size = 14);
plt.xlabel('Date', size = 14);

# %%
# 테스트 시작시 앞의 과거기간이 필요하므로
# train data의 마지막 날짜로부터 args.Lag 만큼의 데이터를 가져와서 test 앞에 붙임
df_test = pd.concat([df_train.iloc[-args.Lag:], df_test])

# %%
if (args.Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')

    scaler = MinMaxScaler()
    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))

elif (args.Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')


    scaler = RobustScaler()
    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))

elif (args.Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    scaler = StandardScaler()

    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))
else:
    print('[WARNING] Unknown data scaling. Standard scaling was selected')

    scaler = StandardScaler()

    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))
# Out:
# [INFO] Scaling: Standard

# %%
def create_dataset(df=None, Lag=1, Horizon=1, targetSeries=None):

    dataX, dataY, dataDate = [], [], []

    # 데이터셋을 생성하기 위한 루프, 0에서 시작해서 데이터프레임의 길이 - Lag - Horizon까지 반복
    for i in tqdm(range(0, df.shape[0] + 1 - Lag - Horizon)):
        # 입력 시퀀스를 dataX에 추가
        dataX.append(df.to_numpy()[i:(i + Lag)])
        # 타겟 시퀀스를 dataY에 추가
        dataY.append(df[targetSeries].to_numpy()[i + Lag : i + Lag + Horizon])
        # 타겟 시퀀스의 날짜를 dataDate에 추가
        dataDate.append(df.index[i + Lag : i + Lag + Horizon].tolist())

    # numpy 배열로 변환하여 반환
    return (np.array(dataX), np.array(dataY), np.array(dataDate))

# %%
print(args.Lag, args.Horizon)
# Out:
# 30 7

# %%
trainX, trainY, _ = create_dataset(df           = df_train,
                                   Lag          = args.Lag,
                                   Horizon      = args.Horizon,
                                   targetSeries = args.targetSeries)


testX,  testY, testDate  = create_dataset(df           = df_test,
                                          Lag          = args.Lag,
                                          Horizon      = args.Horizon,
                                          targetSeries = args.targetSeries)
# Out:
# 100%|██████████| 17161/17161 [00:01<00:00, 17046.05it/s]
# 100%|██████████| 4294/4294 [00:00<00:00, 30329.48it/s]

# %%
# 훈련 데이터의 마지막 10%를 검증용으로 사용
#
# 훈련 데이터에서 검증 데이터로 나누는 인덱스를 계산
idx = int(0.9 * trainX.shape[0])

# 검증 데이터셋을 생성 (마지막 10%)
validX, validY = trainX[idx:], trainY[idx:]

# 훈련 데이터셋을 생성 (처음 90%)
trainX, trainY = trainX[:idx], trainY[:idx]
trainY = np.expand_dims(trainY, axis = -1)
validY = np.expand_dims(validY, axis = -1)
testY  = np.expand_dims(testY,  axis = -1)

# 훈련 데이터셋의 형태 출력
print('Training data shape:   ', trainX.shape, trainY.shape)
# 검증 데이터셋의 형태 출력
print('Validation data shape: ', validX.shape, validY.shape)
# 테스트 데이터셋의 형태 출력
print('Testing data shape:    ', testX.shape,  testY.shape)
# Out:
# Training data shape:    (15444, 30, 1) (15444, 7, 1)
# Validation data shape:  (1717, 30, 1) (1717, 7, 1)
# Testing data shape:     (4294, 30, 1) (4294, 7, 1)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    def __init__(self, X, Y):
        # 데이터를 torch.tensor로 변환하고 데이터 타입을 float32로 설정
        self.X = torch.tensor(X, dtype=torch.float32)
        self.Y = torch.tensor(Y, dtype=torch.float32)
    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# 훈련 및 테스트 데이터로더 생성
#
train_ds = Data(trainX, trainY)
valid_ds = Data(validX, validY)
test_ds  = Data(testX,  testY)

# 데이터 로더 준비
#
train_dl = DataLoader(train_ds, batch_size=args.batch_size, shuffle=False)
valid_dl = DataLoader(valid_ds, batch_size=args.batch_size, shuffle=False)
test_dl  = DataLoader(test_ds,  batch_size=args.batch_size, shuffle=False)

# %% [markdown]
# #### 2) LSTM

# %%
import torch.nn as nn
import torch

class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, num_layers=1, output_length=24):
        """
        LSTM 모델 초기화

        Args:
            input_size (int): 각 시간 단계별 입력 특징 수. 단일 채널의 경우 1.
            hidden_size (int): 은닉 상태의 특징 수.
            num_layers (int): 순환 레이어 수.
            output_length (int): 출력 시퀀스 길이.
        """
        super().__init__()
        self.hidden_size = hidden_size
        self.output_length = output_length
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)  # batch_first=True: (batch_size, seq_len, input_size) 형태의 입력
        self.fc = nn.Linear(hidden_size, output_length)  # 최종 출력

    def forward(self, x):

        # 초기 은닉 상태 (h0) 및 셀 상태 (c0)를 0으로 초기화
        h0 = torch.zeros(self.lstm.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.lstm.num_layers, x.size(0), self.hidden_size).to(device)

        # LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: (batch_size, 입력길이, hidden_size)


       # 마지막 시간 단계의 h만 추출하여 fc 통과
        out = self.fc(out[:, -1, :])  # out: (batch_size, output_length)

        return out.unsqueeze(2)  # out: (batch_size, output_length, 1) 형태로 변환

# %%
# 모델 생성해서 데이터 넣어보기
model = LSTM(input_size=1, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)


# 랜덤 입력값 생성 (예: 배치 크기 32, 입력 길이)
input_data = torch.randn(32, args.Lag, 1).to(device)

# 모델 실행 및 출력 확인
output = model(input_data)
print(f"Output shape: {output.shape}")  # (32, 입력 길이, 1) 형태의 출력
# Out:
# Output shape: torch.Size([32, 7, 1])

# %% [markdown]
# #### 3) 학습

# %%
from EarlyStopping      import *
from LRScheduler        import *


model = LSTM(input_size=1, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)

criterion = nn.MSELoss()

optimizer = torch.optim.Adam(params = model.parameters(),
                             lr     = args.learning_rate)


early_stopping = EarlyStopping(patience  = 10,
                               min_delta = 1e-5)


scheduler = LRScheduler(optimizer = optimizer,
                        patience  = 3,
                        min_lr    = 1e-10,
                        factor    = 0.5)

# %%
# 훈련 및 검증 손실 저장
Loss = {
         'Train': [],
         'Valid':  []
       }

# 메인 루프 - 훈련 과정
for epoch in range(1, args.epochs+1):

    # 타이머 시작
    start = time.time()

    # 훈련 손실 모니터링
    train_loss = 0.0
    valid_loss  = 0.0

    ###################
    # 모델 훈련하기 #
    ###################

    for data, target in train_dl:

        #  기울기 초기화
        optimizer.zero_grad()

        data   = data.cuda()
        target = target.cuda()

        outputs = model(data)
        outputs = outputs
        # 손실 계산

        loss = criterion(outputs, target)

        # 기울기 계산
        loss.backward()

        # 업데이트
        optimizer.step()

        train_loss += loss.item() * data.size(0)


    train_loss = train_loss / train_dl.dataset.X.shape[0]

    with torch.no_grad():
        for data, target in valid_dl:

            data   = data.cuda()
            target = target.cuda()

            outputs = model(data)

            # 손실 계산
            loss = criterion(outputs, target)

            # 실행 중인 검증 손실 업데이트
            valid_loss += loss.item() * data.size(0)

    # 평균 훈련 통계 출력
    valid_loss = valid_loss / test_dl.dataset.X.shape[0]

    # 타이머 정지
    stop = time.time()

    # 훈련 결과 출력
    print('\n[INFO] Epoch: {} \tTrain Loss: {:.6f}\tValid Loss: {:.6f} \tTime: {:.2f}secs'.format(epoch, train_loss, valid_loss, stop-start), end=' ')

    # 최적 모델 업데이트
    if (epoch == 1):
        Best_score = valid_loss

        torch.save(model.state_dict(), "./" + args.model_name + ".pth")
        print('(모델 저장됨)\n')
    else:
        if (Best_score > valid_loss):
            Best_score = valid_loss

            torch.save(model.state_dict(), "./" + args.model_name + ".pth")
            print('(모델 저장됨)\n')
        else:
            print('\n')

    # 훈련/검증 손실 저장
    Loss['Train'] += [train_loss]
    Loss['Valid'] += [valid_loss]

    # 학습률 스케줄러
    scheduler(valid_loss)

    # 조기 종료
    if (early_stopping(valid_loss)):
        break
# Out:
# [INFO] Epoch: 1 	Train Loss: 0.580253	Valid Loss: 0.111840 	Time: 3.62secs (모델 저장됨)
#
#
# [INFO] Epoch: 2 	Train Loss: 0.397020	Valid Loss: 0.069039 	Time: 3.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 3 	Train Loss: 0.379666	Valid Loss: 0.060070 	Time: 4.12secs (모델 저장됨)
#
#
# [INFO] Epoch: 4 	Train Loss: 0.370778	Valid Loss: 0.057431 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 5 	Train Loss: 0.365974	Valid Loss: 0.055737 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 6 	Train Loss: 0.363193	Valid Loss: 0.053993 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 7 	Train Loss: 0.361342	Valid Loss: 0.052135 	Time: 4.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 8 	Train Loss: 0.359957	Valid Loss: 0.050280 	Time: 3.06secs (모델 저장됨)
#
#
# [INFO] Epoch: 9 	Train Loss: 0.358841	Valid Loss: 0.048531 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 10 	Train Loss: 0.357901	Valid Loss: 0.046952 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 11 	Train Loss: 0.357088	Valid Loss: 0.045570 	Time: 3.74secs (모델 저장됨)
#
#
# [INFO] Epoch: 12 	Train Loss: 0.356368	Valid Loss: 0.044376 	Time: 3.33secs (모델 저장됨)
#
#
# [INFO] Epoch: 13 	Train Loss: 0.355714	Valid Loss: 0.043341 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 14 	Train Loss: 0.355104	Valid Loss: 0.042433 	Time: 3.12secs (모델 저장됨)
#
#
# [INFO] Epoch: 15 	Train Loss: 0.354519	Valid Loss: 0.041624 	Time: 3.63secs (모델 저장됨)
#
#
# [INFO] Epoch: 16 	Train Loss: 0.353939	Valid Loss: 0.040892 	Time: 3.47secs (모델 저장됨)
#
#
# [INFO] Epoch: 17 	Train Loss: 0.353342	Valid Loss: 0.040218 	Time: 3.06secs (모델 저장됨)
#
#
# [INFO] Epoch: 18 	Train Loss: 0.352696	Valid Loss: 0.039590 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 19 	Train Loss: 0.351955	Valid Loss: 0.039001 	Time: 3.47secs (모델 저장됨)
#
#
# [INFO] Epoch: 20 	Train Loss: 0.351052	Valid Loss: 0.038456 	Time: 3.63secs (모델 저장됨)
#
#
# [INFO] Epoch: 21 	Train Loss: 0.349892	Valid Loss: 0.037936 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 22 	Train Loss: 0.348234	Valid Loss: 0.037344 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 23 	Train Loss: 0.345863	Valid Loss: 0.036718 	Time: 3.22secs (모델 저장됨)
#
#
# [INFO] Epoch: 24 	Train Loss: 0.342462	Valid Loss: 0.036130 	Time: 5.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 25 	Train Loss: 0.337407	Valid Loss: 0.035706 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 26 	Train Loss: 0.329727	Valid Loss: 0.035331 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 27 	Train Loss: 0.319339	Valid Loss: 0.034525 	Time: 3.32secs (모델 저장됨)
#
#
# [INFO] Epoch: 28 	Train Loss: 0.307393	Valid Loss: 0.032644 	Time: 3.61secs (모델 저장됨)
#
#
# [INFO] Epoch: 29 	Train Loss: 0.293598	Valid Loss: 0.031709 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 30 	Train Loss: 0.278711	Valid Loss: 0.031492 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 31 	Train Loss: 0.266171	Valid Loss: 0.027441 	Time: 3.25secs (모델 저장됨)
#
#
# [INFO] Epoch: 32 	Train Loss: 0.259490	Valid Loss: 0.026565 	Time: 3.82secs (모델 저장됨)
#
#
# [INFO] Epoch: 33 	Train Loss: 0.255742	Valid Loss: 0.026352 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 34 	Train Loss: 0.252862	Valid Loss: 0.027132 	Time: 2.98secs
#
#
# [INFO] Epoch: 35 	Train Loss: 0.250009	Valid Loss: 0.028038 	Time: 3.04secs
#
#
# [INFO] Epoch: 36 	Train Loss: 0.247060	Valid Loss: 0.028882 	Time: 4.03secs
#
#
# [INFO] Epoch: 37 	Train Loss: 0.244796	Valid Loss: 0.030102 	Time: 3.01secs
#
#
# [INFO] Epoch: 38 	Train Loss: 0.241880	Valid Loss: 0.025246 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 39 	Train Loss: 0.238379	Valid Loss: 0.024425 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 40 	Train Loss: 0.236885	Valid Loss: 0.024266 	Time: 4.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 41 	Train Loss: 0.235684	Valid Loss: 0.024200 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 42 	Train Loss: 0.234610	Valid Loss: 0.024238 	Time: 2.97secs
#
#
# [INFO] Epoch: 43 	Train Loss: 0.233624	Valid Loss: 0.024383 	Time: 2.99secs
#
#
# [INFO] Epoch: 44 	Train Loss: 0.232706	Valid Loss: 0.024612 	Time: 3.92secs
#
#
# [INFO] Epoch: 45 	Train Loss: 0.231847	Valid Loss: 0.024902 	Time: 3.13secs
#
#
# [INFO] Epoch: 46 	Train Loss: 0.231351	Valid Loss: 0.019272 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 47 	Train Loss: 0.229721	Valid Loss: 0.019164 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 48 	Train Loss: 0.229200	Valid Loss: 0.019232 	Time: 3.67secs
#
#
# [INFO] Epoch: 49 	Train Loss: 0.228751	Valid Loss: 0.019305 	Time: 3.40secs
#
#
# [INFO] Epoch: 50 	Train Loss: 0.228332	Valid Loss: 0.019375 	Time: 2.99secs
#
#
# [INFO] Epoch: 51 	Train Loss: 0.227933	Valid Loss: 0.019437 	Time: 2.99secs
#
#
# [INFO] Epoch: 52 	Train Loss: 0.228027	Valid Loss: 0.016986 	Time: 3.50secs (모델 저장됨)
#
#
# [INFO] Epoch: 53 	Train Loss: 0.227290	Valid Loss: 0.016661 	Time: 3.56secs (모델 저장됨)
#
#
# [INFO] Epoch: 54 	Train Loss: 0.227024	Valid Loss: 0.016516 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 55 	Train Loss: 0.226800	Valid Loss: 0.016443 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 56 	Train Loss: 0.226592	Valid Loss: 0.016402 	Time: 3.34secs (모델 저장됨)
#
#
# [INFO] Epoch: 57 	Train Loss: 0.226394	Valid Loss: 0.016377 	Time: 3.75secs (모델 저장됨)
#
#
# [INFO] Epoch: 58 	Train Loss: 0.226203	Valid Loss: 0.016359 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 59 	Train Loss: 0.226017	Valid Loss: 0.016345 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 60 	Train Loss: 0.225837	Valid Loss: 0.016331 	Time: 3.09secs (모델 저장됨)
#
#
# [INFO] Epoch: 61 	Train Loss: 0.225661	Valid Loss: 0.016317 	Time: 3.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 62 	Train Loss: 0.225489	Valid Loss: 0.016303 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 63 	Train Loss: 0.225320	Valid Loss: 0.016289 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 64 	Train Loss: 0.225155	Valid Loss: 0.016274 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 65 	Train Loss: 0.224993	Valid Loss: 0.016258 	Time: 4.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 66 	Train Loss: 0.224834	Valid Loss: 0.016242 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 67 	Train Loss: 0.224678	Valid Loss: 0.016226 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 68 	Train Loss: 0.224524	Valid Loss: 0.016209 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 69 	Train Loss: 0.224374	Valid Loss: 0.016192 	Time: 4.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 70 	Train Loss: 0.224225	Valid Loss: 0.016175 	Time: 3.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 71 	Train Loss: 0.224079	Valid Loss: 0.016158 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 72 	Train Loss: 0.223936	Valid Loss: 0.016141 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 73 	Train Loss: 0.223795	Valid Loss: 0.016124 	Time: 3.74secs (모델 저장됨)
#
#
# [INFO] Epoch: 74 	Train Loss: 0.223656	Valid Loss: 0.016107 	Time: 3.24secs (모델 저장됨)
#
#
# [INFO] Epoch: 75 	Train Loss: 0.223519	Valid Loss: 0.016091 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 76 	Train Loss: 0.223384	Valid Loss: 0.016074 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 77 	Train Loss: 0.223250	Valid Loss: 0.016057 	Time: 3.56secs (모델 저장됨)
#
#
# [INFO] Epoch: 78 	Train Loss: 0.223119	Valid Loss: 0.016041 	Time: 3.45secs (모델 저장됨)
#
#
# [INFO] Epoch: 79 	Train Loss: 0.222990	Valid Loss: 0.016025 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 80 	Train Loss: 0.222863	Valid Loss: 0.016008 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 81 	Train Loss: 0.222737	Valid Loss: 0.015992 	Time: 3.44secs (모델 저장됨)
#
#
# [INFO] Epoch: 82 	Train Loss: 0.222613	Valid Loss: 0.015977 	Time: 3.70secs (모델 저장됨)
#
#
# [INFO] Epoch: 83 	Train Loss: 0.222490	Valid Loss: 0.015961 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 84 	Train Loss: 0.222369	Valid Loss: 0.015946 	Time: 2.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 85 	Train Loss: 0.222250	Valid Loss: 0.015930 	Time: 3.09secs (모델 저장됨)
#
#
# [INFO] Epoch: 86 	Train Loss: 0.222132	Valid Loss: 0.015915 	Time: 3.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 87 	Train Loss: 0.222015	Valid Loss: 0.015900 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 88 	Train Loss: 0.221900	Valid Loss: 0.015886 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 89 	Train Loss: 0.221786	Valid Loss: 0.015871 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 90 	Train Loss: 0.221674	Valid Loss: 0.015856 	Time: 4.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 91 	Train Loss: 0.221563	Valid Loss: 0.015842 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 92 	Train Loss: 0.221453	Valid Loss: 0.015828 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 93 	Train Loss: 0.221344	Valid Loss: 0.015813 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 94 	Train Loss: 0.221236	Valid Loss: 0.015799 	Time: 3.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 95 	Train Loss: 0.221130	Valid Loss: 0.015785 	Time: 3.15secs (모델 저장됨)
#
#
# [INFO] Epoch: 96 	Train Loss: 0.221024	Valid Loss: 0.015771 	Time: 3.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 97 	Train Loss: 0.220920	Valid Loss: 0.015757 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 98 	Train Loss: 0.220817	Valid Loss: 0.015743 	Time: 3.79secs (모델 저장됨)
#
#
# [INFO] Epoch: 99 	Train Loss: 0.220715	Valid Loss: 0.015729 	Time: 3.30secs (모델 저장됨)
#
#
# [INFO] Epoch: 100 	Train Loss: 0.220614	Valid Loss: 0.015714 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 101 	Train Loss: 0.220513	Valid Loss: 0.015700 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 102 	Train Loss: 0.220414	Valid Loss: 0.015686 	Time: 3.55secs (모델 저장됨)
#
#
# [INFO] Epoch: 103 	Train Loss: 0.220316	Valid Loss: 0.015672 	Time: 3.42secs (모델 저장됨)
#
#
# [INFO] Epoch: 104 	Train Loss: 0.220218	Valid Loss: 0.015658 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 105 	Train Loss: 0.220121	Valid Loss: 0.015644 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 106 	Train Loss: 0.220025	Valid Loss: 0.015629 	Time: 3.41secs (모델 저장됨)
#
#
# [INFO] Epoch: 107 	Train Loss: 0.219930	Valid Loss: 0.015615 	Time: 3.51secs (모델 저장됨)
#
#
# [INFO] Epoch: 108 	Train Loss: 0.219836	Valid Loss: 0.015600 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 109 	Train Loss: 0.219743	Valid Loss: 0.015586 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 110 	Train Loss: 0.219650	Valid Loss: 0.015571 	Time: 3.28secs (모델 저장됨)
#
#
# [INFO] Epoch: 111 	Train Loss: 0.219558	Valid Loss: 0.015557 	Time: 3.78secs (모델 저장됨)
#
#
# [INFO] Epoch: 112 	Train Loss: 0.219467	Valid Loss: 0.015542 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 113 	Train Loss: 0.219376	Valid Loss: 0.015527 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 114 	Train Loss: 0.219286	Valid Loss: 0.015512 	Time: 3.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 115 	Train Loss: 0.219197	Valid Loss: 0.015497 	Time: 3.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 116 	Train Loss: 0.219108	Valid Loss: 0.015482 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 117 	Train Loss: 0.219020	Valid Loss: 0.015467 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 118 	Train Loss: 0.218932	Valid Loss: 0.015452 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 119 	Train Loss: 0.218846	Valid Loss: 0.015437 	Time: 4.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 120 	Train Loss: 0.218759	Valid Loss: 0.015421 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 121 	Train Loss: 0.218673	Valid Loss: 0.015406 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 122 	Train Loss: 0.218588	Valid Loss: 0.015391 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 123 	Train Loss: 0.218504	Valid Loss: 0.015376 	Time: 3.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 124 	Train Loss: 0.218419	Valid Loss: 0.015361 	Time: 3.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 125 	Train Loss: 0.218336	Valid Loss: 0.015346 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 126 	Train Loss: 0.218253	Valid Loss: 0.015331 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 127 	Train Loss: 0.218170	Valid Loss: 0.015316 	Time: 3.70secs (모델 저장됨)
#
#
# [INFO] Epoch: 128 	Train Loss: 0.218088	Valid Loss: 0.015301 	Time: 3.37secs (모델 저장됨)
#
#
# [INFO] Epoch: 129 	Train Loss: 0.218006	Valid Loss: 0.015286 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 130 	Train Loss: 0.217925	Valid Loss: 0.015271 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 131 	Train Loss: 0.217844	Valid Loss: 0.015257 	Time: 3.52secs (모델 저장됨)
#
#
# [INFO] Epoch: 132 	Train Loss: 0.217764	Valid Loss: 0.015242 	Time: 3.52secs (모델 저장됨)
#
#
# [INFO] Epoch: 133 	Train Loss: 0.217684	Valid Loss: 0.015228 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 134 	Train Loss: 0.217605	Valid Loss: 0.015214 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 135 	Train Loss: 0.217526	Valid Loss: 0.015200 	Time: 3.27secs (모델 저장됨)
#
#
# [INFO] Epoch: 136 	Train Loss: 0.217447	Valid Loss: 0.015186 	Time: 3.77secs (모델 저장됨)
#
#
# [INFO] Epoch: 137 	Train Loss: 0.217369	Valid Loss: 0.015173 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 138 	Train Loss: 0.217291	Valid Loss: 0.015160 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 139 	Train Loss: 0.217214	Valid Loss: 0.015147 	Time: 3.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 140 	Train Loss: 0.217137	Valid Loss: 0.015134 	Time: 4.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 141 	Train Loss: 0.217061	Valid Loss: 0.015121 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 142 	Train Loss: 0.216985	Valid Loss: 0.015109 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 143 	Train Loss: 0.216909	Valid Loss: 0.015096 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 144 	Train Loss: 0.216833	Valid Loss: 0.015084 	Time: 4.11secs (모델 저장됨)
#
#
# [INFO] Epoch: 145 	Train Loss: 0.216758	Valid Loss: 0.015073 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 146 	Train Loss: 0.216684	Valid Loss: 0.015061 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 147 	Train Loss: 0.216609	Valid Loss: 0.015050 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 148 	Train Loss: 0.216535	Valid Loss: 0.015039 	Time: 3.84secs (모델 저장됨)
#
#
# [INFO] Epoch: 149 	Train Loss: 0.216462	Valid Loss: 0.015028 	Time: 3.19secs (모델 저장됨)
#
#
# [INFO] Epoch: 150 	Train Loss: 0.216389	Valid Loss: 0.015018 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 151 	Train Loss: 0.216316	Valid Loss: 0.015008 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 152 	Train Loss: 0.216243	Valid Loss: 0.014998 	Time: 3.58secs (모델 저장됨)
#
#
# [INFO] Epoch: 153 	Train Loss: 0.216171	Valid Loss: 0.014988 	Time: 3.43secs (모델 저장됨)
#
#
# [INFO] Epoch: 154 	Train Loss: 0.216099	Valid Loss: 0.014978 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 155 	Train Loss: 0.216027	Valid Loss: 0.014969 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 156 	Train Loss: 0.215956	Valid Loss: 0.014960 	Time: 3.46secs (모델 저장됨)
#
#
# [INFO] Epoch: 157 	Train Loss: 0.215885	Valid Loss: 0.014951 	Time: 3.56secs (모델 저장됨)
#
#
# [INFO] Epoch: 158 	Train Loss: 0.215814	Valid Loss: 0.014943 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 159 	Train Loss: 0.215744	Valid Loss: 0.014934 	Time: 2.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 160 	Train Loss: 0.215674	Valid Loss: 0.014926 	Time: 3.26secs (모델 저장됨)
#
#
# [INFO] Epoch: 161 	Train Loss: 0.215604	Valid Loss: 0.014918 	Time: 3.75secs (모델 저장됨)
#
#
# [INFO] Epoch: 162 	Train Loss: 0.215534	Valid Loss: 0.014911 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 163 	Train Loss: 0.215465	Valid Loss: 0.014903 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 164 	Train Loss: 0.215396	Valid Loss: 0.014896 	Time: 3.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 165 	Train Loss: 0.215327	Valid Loss: 0.014888 	Time: 3.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 166 	Train Loss: 0.215259	Valid Loss: 0.014881 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 167 	Train Loss: 0.215191	Valid Loss: 0.014875 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 168 	Train Loss: 0.215123	Valid Loss: 0.014868 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 169 	Train Loss: 0.215055	Valid Loss: 0.014862 	Time: 4.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 170 	Train Loss: 0.214988	Valid Loss: 0.014855 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 171 	Train Loss: 0.214920	Valid Loss: 0.014849 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 172 	Train Loss: 0.214854	Valid Loss: 0.014843 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 173 	Train Loss: 0.214787	Valid Loss: 0.014837 	Time: 3.92secs (모델 저장됨)
#
#
# [INFO] Epoch: 174 	Train Loss: 0.214720	Valid Loss: 0.014832 	Time: 3.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 175 	Train Loss: 0.214654	Valid Loss: 0.014826 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 176 	Train Loss: 0.214588	Valid Loss: 0.014821 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 177 	Train Loss: 0.214522	Valid Loss: 0.014816 	Time: 3.69secs (모델 저장됨)
#
#
# [INFO] Epoch: 178 	Train Loss: 0.214457	Valid Loss: 0.014811 	Time: 3.38secs (모델 저장됨)
#
#
# [INFO] Epoch: 179 	Train Loss: 0.214391	Valid Loss: 0.014806 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 180 	Train Loss: 0.214326	Valid Loss: 0.014801 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 181 	Train Loss: 0.214261	Valid Loss: 0.014796 	Time: 3.51secs (모델 저장됨)
#
#
# [INFO] Epoch: 182 	Train Loss: 0.214197	Valid Loss: 0.014791 	Time: 3.53secs (모델 저장됨)
#
#
# [INFO] Epoch: 183 	Train Loss: 0.214132	Valid Loss: 0.014787 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 184 	Train Loss: 0.214068	Valid Loss: 0.014782 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 185 	Train Loss: 0.214004	Valid Loss: 0.014778 	Time: 3.28secs (모델 저장됨)
#
#
# [INFO] Epoch: 186 	Train Loss: 0.213940	Valid Loss: 0.014774 	Time: 3.69secs (모델 저장됨)
#
#
# [INFO] Epoch: 187 	Train Loss: 0.213876	Valid Loss: 0.014769 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 188 	Train Loss: 0.213813	Valid Loss: 0.014765 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 189 	Train Loss: 0.213750	Valid Loss: 0.014761 	Time: 3.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 190 	Train Loss: 0.213687	Valid Loss: 0.014757 	Time: 3.88secs (모델 저장됨)
#
#
# [INFO] Epoch: 191 	Train Loss: 0.213624	Valid Loss: 0.014753 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 192 	Train Loss: 0.213561	Valid Loss: 0.014750 	Time: 3.06secs (모델 저장됨)
#
#
# [INFO] Epoch: 193 	Train Loss: 0.213499	Valid Loss: 0.014746 	Time: 3.13secs (모델 저장됨)
#
#
# [INFO] Epoch: 194 	Train Loss: 0.213437	Valid Loss: 0.014742 	Time: 3.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 195 	Train Loss: 0.213375	Valid Loss: 0.014739 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 196 	Train Loss: 0.213313	Valid Loss: 0.014735 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 197 	Train Loss: 0.213251	Valid Loss: 0.014731 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 198 	Train Loss: 0.213189	Valid Loss: 0.014728 	Time: 4.08secs (모델 저장됨)
#
#
# [INFO] Epoch: 199 	Train Loss: 0.213128	Valid Loss: 0.014725 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 200 	Train Loss: 0.213067	Valid Loss: 0.014721 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 201 	Train Loss: 0.213006	Valid Loss: 0.014718 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 202 	Train Loss: 0.212945	Valid Loss: 0.014714 	Time: 3.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 203 	Train Loss: 0.212885	Valid Loss: 0.014711 	Time: 3.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 204 	Train Loss: 0.212824	Valid Loss: 0.014708 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 205 	Train Loss: 0.212764	Valid Loss: 0.014705 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 206 	Train Loss: 0.212704	Valid Loss: 0.014701 	Time: 3.75secs (모델 저장됨)
#
#
# [INFO] Epoch: 207 	Train Loss: 0.212644	Valid Loss: 0.014698 	Time: 3.26secs (모델 저장됨)
#
#
# [INFO] Epoch: 208 	Train Loss: 0.212585	Valid Loss: 0.014695 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 209 	Train Loss: 0.212525	Valid Loss: 0.014692 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 210 	Train Loss: 0.212466	Valid Loss: 0.014688 	Time: 3.48secs (모델 저장됨)
#
#
# [INFO] Epoch: 211 	Train Loss: 0.212407	Valid Loss: 0.014685 	Time: 3.56secs (모델 저장됨)
#
#
# [INFO] Epoch: 212 	Train Loss: 0.212348	Valid Loss: 0.014682 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 213 	Train Loss: 0.212289	Valid Loss: 0.014679 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 214 	Train Loss: 0.212230	Valid Loss: 0.014675 	Time: 3.27secs (모델 저장됨)
#
#
# [INFO] Epoch: 215 	Train Loss: 0.212172	Valid Loss: 0.014672 	Time: 3.80secs (모델 저장됨)
#
#
# [INFO] Epoch: 216 	Train Loss: 0.212114	Valid Loss: 0.014669 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 217 	Train Loss: 0.212056	Valid Loss: 0.014665 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 218 	Train Loss: 0.211998	Valid Loss: 0.014662 	Time: 3.08secs (모델 저장됨)
#
#
# [INFO] Epoch: 219 	Train Loss: 0.211940	Valid Loss: 0.014659 	Time: 4.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 220 	Train Loss: 0.211882	Valid Loss: 0.014655 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 221 	Train Loss: 0.211825	Valid Loss: 0.014652 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 222 	Train Loss: 0.211768	Valid Loss: 0.014648 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 223 	Train Loss: 0.211711	Valid Loss: 0.014645 	Time: 4.11secs (모델 저장됨)
#
#
# [INFO] Epoch: 224 	Train Loss: 0.211654	Valid Loss: 0.014641 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 225 	Train Loss: 0.211597	Valid Loss: 0.014638 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 226 	Train Loss: 0.211540	Valid Loss: 0.014634 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 227 	Train Loss: 0.211484	Valid Loss: 0.014631 	Time: 3.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 228 	Train Loss: 0.211428	Valid Loss: 0.014627 	Time: 3.17secs (모델 저장됨)
#
#
# [INFO] Epoch: 229 	Train Loss: 0.211372	Valid Loss: 0.014623 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 230 	Train Loss: 0.211316	Valid Loss: 0.014619 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 231 	Train Loss: 0.211260	Valid Loss: 0.014616 	Time: 3.61secs (모델 저장됨)
#
#
# [INFO] Epoch: 232 	Train Loss: 0.211204	Valid Loss: 0.014612 	Time: 3.36secs (모델 저장됨)
#
#
# [INFO] Epoch: 233 	Train Loss: 0.211149	Valid Loss: 0.014608 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 234 	Train Loss: 0.211094	Valid Loss: 0.014604 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 235 	Train Loss: 0.211039	Valid Loss: 0.014600 	Time: 3.49secs (모델 저장됨)
#
#
# [INFO] Epoch: 236 	Train Loss: 0.210984	Valid Loss: 0.014596 	Time: 3.49secs (모델 저장됨)
#
#
# [INFO] Epoch: 237 	Train Loss: 0.210929	Valid Loss: 0.014592 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 238 	Train Loss: 0.210874	Valid Loss: 0.014587 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 239 	Train Loss: 0.210820	Valid Loss: 0.014583 	Time: 3.33secs (모델 저장됨)
#
#
# [INFO] Epoch: 240 	Train Loss: 0.210765	Valid Loss: 0.014579 	Time: 3.75secs (모델 저장됨)
#
#
# [INFO] Epoch: 241 	Train Loss: 0.210711	Valid Loss: 0.014574 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 242 	Train Loss: 0.210657	Valid Loss: 0.014570 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 243 	Train Loss: 0.210603	Valid Loss: 0.014566 	Time: 3.12secs (모델 저장됨)
#
#
# [INFO] Epoch: 244 	Train Loss: 0.210550	Valid Loss: 0.014561 	Time: 3.86secs (모델 저장됨)
#
#
# [INFO] Epoch: 245 	Train Loss: 0.210496	Valid Loss: 0.014556 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 246 	Train Loss: 0.210443	Valid Loss: 0.014552 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 247 	Train Loss: 0.210389	Valid Loss: 0.014547 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 248 	Train Loss: 0.210336	Valid Loss: 0.014542 	Time: 4.08secs (모델 저장됨)
#
#
# [INFO] Epoch: 249 	Train Loss: 0.210283	Valid Loss: 0.014537 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 250 	Train Loss: 0.210231	Valid Loss: 0.014532 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 251 	Train Loss: 0.210178	Valid Loss: 0.014527 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 252 	Train Loss: 0.210126	Valid Loss: 0.014522 	Time: 4.11secs (모델 저장됨)
#
#
# [INFO] Epoch: 253 	Train Loss: 0.210073	Valid Loss: 0.014517 	Time: 3.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 254 	Train Loss: 0.210021	Valid Loss: 0.014512 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 255 	Train Loss: 0.209969	Valid Loss: 0.014507 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 256 	Train Loss: 0.209917	Valid Loss: 0.014502 	Time: 3.88secs (모델 저장됨)
#
#
# [INFO] Epoch: 257 	Train Loss: 0.209866	Valid Loss: 0.014496 	Time: 3.25secs (모델 저장됨)
#
#
# [INFO] Epoch: 258 	Train Loss: 0.209814	Valid Loss: 0.014491 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 259 	Train Loss: 0.209763	Valid Loss: 0.014485 	Time: 2.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 260 	Train Loss: 0.209711	Valid Loss: 0.014480 	Time: 3.58secs (모델 저장됨)
#
#
# [INFO] Epoch: 261 	Train Loss: 0.209660	Valid Loss: 0.014474 	Time: 3.51secs (모델 저장됨)
#
#
# [INFO] Epoch: 262 	Train Loss: 0.209609	Valid Loss: 0.014469 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 263 	Train Loss: 0.209558	Valid Loss: 0.014463 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 264 	Train Loss: 0.209508	Valid Loss: 0.014457 	Time: 3.40secs (모델 저장됨)
#
#
# [INFO] Epoch: 265 	Train Loss: 0.209457	Valid Loss: 0.014452 	Time: 3.68secs (모델 저장됨)
#
#
# [INFO] Epoch: 266 	Train Loss: 0.209407	Valid Loss: 0.014446 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 267 	Train Loss: 0.209357	Valid Loss: 0.014440 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 268 	Train Loss: 0.209307	Valid Loss: 0.014434 	Time: 3.16secs (모델 저장됨)
#
#
# [INFO] Epoch: 269 	Train Loss: 0.209257	Valid Loss: 0.014428 	Time: 3.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 270 	Train Loss: 0.209207	Valid Loss: 0.014422 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 271 	Train Loss: 0.209157	Valid Loss: 0.014416 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 272 	Train Loss: 0.209108	Valid Loss: 0.014410 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 273 	Train Loss: 0.209058	Valid Loss: 0.014404 	Time: 4.11secs (모델 저장됨)
#
#
# [INFO] Epoch: 274 	Train Loss: 0.209009	Valid Loss: 0.014397 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 275 	Train Loss: 0.208960	Valid Loss: 0.014391 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 276 	Train Loss: 0.208911	Valid Loss: 0.014385 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 277 	Train Loss: 0.208862	Valid Loss: 0.014378 	Time: 3.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 278 	Train Loss: 0.208814	Valid Loss: 0.014372 	Time: 3.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 279 	Train Loss: 0.208765	Valid Loss: 0.014366 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 280 	Train Loss: 0.208717	Valid Loss: 0.014359 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 281 	Train Loss: 0.208669	Valid Loss: 0.014353 	Time: 3.66secs (모델 저장됨)
#
#
# [INFO] Epoch: 282 	Train Loss: 0.208621	Valid Loss: 0.014346 	Time: 3.41secs (모델 저장됨)
#
#
# [INFO] Epoch: 283 	Train Loss: 0.208573	Valid Loss: 0.014340 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 284 	Train Loss: 0.208525	Valid Loss: 0.014333 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 285 	Train Loss: 0.208478	Valid Loss: 0.014326 	Time: 3.58secs (모델 저장됨)
#
#
# [INFO] Epoch: 286 	Train Loss: 0.208430	Valid Loss: 0.014320 	Time: 3.62secs (모델 저장됨)
#
#
# [INFO] Epoch: 287 	Train Loss: 0.208383	Valid Loss: 0.014313 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 288 	Train Loss: 0.208336	Valid Loss: 0.014306 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 289 	Train Loss: 0.208289	Valid Loss: 0.014300 	Time: 3.44secs (모델 저장됨)
#
#
# [INFO] Epoch: 290 	Train Loss: 0.208242	Valid Loss: 0.014293 	Time: 3.71secs (모델 저장됨)
#
#
# [INFO] Epoch: 291 	Train Loss: 0.208195	Valid Loss: 0.014286 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 292 	Train Loss: 0.208148	Valid Loss: 0.014280 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 293 	Train Loss: 0.208102	Valid Loss: 0.014273 	Time: 3.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 294 	Train Loss: 0.208056	Valid Loss: 0.014266 	Time: 3.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 295 	Train Loss: 0.208009	Valid Loss: 0.014259 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 296 	Train Loss: 0.207963	Valid Loss: 0.014252 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 297 	Train Loss: 0.207918	Valid Loss: 0.014245 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 298 	Train Loss: 0.207872	Valid Loss: 0.014239 	Time: 4.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 299 	Train Loss: 0.207826	Valid Loss: 0.014232 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 300 	Train Loss: 0.207781	Valid Loss: 0.014225 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 301 	Train Loss: 0.207736	Valid Loss: 0.014218 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 302 	Train Loss: 0.207690	Valid Loss: 0.014211 	Time: 3.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 303 	Train Loss: 0.207645	Valid Loss: 0.014204 	Time: 3.09secs (모델 저장됨)
#
#
# [INFO] Epoch: 304 	Train Loss: 0.207600	Valid Loss: 0.014197 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 305 	Train Loss: 0.207556	Valid Loss: 0.014190 	Time: 3.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 306 	Train Loss: 0.207511	Valid Loss: 0.014183 	Time: 3.71secs (모델 저장됨)
#
#
# [INFO] Epoch: 307 	Train Loss: 0.207467	Valid Loss: 0.014176 	Time: 3.28secs (모델 저장됨)
#
#
# [INFO] Epoch: 308 	Train Loss: 0.207422	Valid Loss: 0.014169 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 309 	Train Loss: 0.207378	Valid Loss: 0.014162 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 310 	Train Loss: 0.207334	Valid Loss: 0.014155 	Time: 3.54secs (모델 저장됨)
#
#
# [INFO] Epoch: 311 	Train Loss: 0.207290	Valid Loss: 0.014149 	Time: 5.29secs (모델 저장됨)
#
#
# [INFO] Epoch: 312 	Train Loss: 0.207246	Valid Loss: 0.014142 	Time: 5.47secs (모델 저장됨)
#
#
# [INFO] Epoch: 313 	Train Loss: 0.207203	Valid Loss: 0.014135 	Time: 4.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 314 	Train Loss: 0.207159	Valid Loss: 0.014128 	Time: 3.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 315 	Train Loss: 0.207116	Valid Loss: 0.014121 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 316 	Train Loss: 0.207073	Valid Loss: 0.014114 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 317 	Train Loss: 0.207030	Valid Loss: 0.014107 	Time: 3.79secs (모델 저장됨)
#
#
# [INFO] Epoch: 318 	Train Loss: 0.206987	Valid Loss: 0.014100 	Time: 3.26secs (모델 저장됨)
#
#
# [INFO] Epoch: 319 	Train Loss: 0.206944	Valid Loss: 0.014093 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 320 	Train Loss: 0.206901	Valid Loss: 0.014086 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 321 	Train Loss: 0.206859	Valid Loss: 0.014080 	Time: 3.54secs (모델 저장됨)
#
#
# [INFO] Epoch: 322 	Train Loss: 0.206816	Valid Loss: 0.014073 	Time: 3.60secs (모델 저장됨)
#
#
# [INFO] Epoch: 323 	Train Loss: 0.206774	Valid Loss: 0.014066 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 324 	Train Loss: 0.206732	Valid Loss: 0.014059 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 325 	Train Loss: 0.206690	Valid Loss: 0.014052 	Time: 3.27secs (모델 저장됨)
#
#
# [INFO] Epoch: 326 	Train Loss: 0.206648	Valid Loss: 0.014046 	Time: 3.72secs (모델 저장됨)
#
#
# [INFO] Epoch: 327 	Train Loss: 0.206606	Valid Loss: 0.014039 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 328 	Train Loss: 0.206565	Valid Loss: 0.014032 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 329 	Train Loss: 0.206523	Valid Loss: 0.014025 	Time: 3.11secs (모델 저장됨)
#
#
# [INFO] Epoch: 330 	Train Loss: 0.206482	Valid Loss: 0.014019 	Time: 3.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 331 	Train Loss: 0.206441	Valid Loss: 0.014012 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 332 	Train Loss: 0.206399	Valid Loss: 0.014005 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 333 	Train Loss: 0.206358	Valid Loss: 0.013999 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 334 	Train Loss: 0.206318	Valid Loss: 0.013992 	Time: 4.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 335 	Train Loss: 0.206277	Valid Loss: 0.013985 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 336 	Train Loss: 0.206236	Valid Loss: 0.013979 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 337 	Train Loss: 0.206196	Valid Loss: 0.013972 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 338 	Train Loss: 0.206155	Valid Loss: 0.013966 	Time: 4.08secs (모델 저장됨)
#
#
# [INFO] Epoch: 339 	Train Loss: 0.206115	Valid Loss: 0.013959 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 340 	Train Loss: 0.206075	Valid Loss: 0.013953 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 341 	Train Loss: 0.206035	Valid Loss: 0.013946 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 342 	Train Loss: 0.205995	Valid Loss: 0.013940 	Time: 4.70secs (모델 저장됨)
#
#
# [INFO] Epoch: 343 	Train Loss: 0.205955	Valid Loss: 0.013933 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 344 	Train Loss: 0.205916	Valid Loss: 0.013927 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 345 	Train Loss: 0.205876	Valid Loss: 0.013920 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 346 	Train Loss: 0.205837	Valid Loss: 0.013914 	Time: 3.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 347 	Train Loss: 0.205797	Valid Loss: 0.013908 	Time: 3.21secs (모델 저장됨)
#
#
# [INFO] Epoch: 348 	Train Loss: 0.205758	Valid Loss: 0.013901 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 349 	Train Loss: 0.205719	Valid Loss: 0.013895 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 350 	Train Loss: 0.205680	Valid Loss: 0.013889 	Time: 3.71secs (모델 저장됨)
#
#
# [INFO] Epoch: 351 	Train Loss: 0.205641	Valid Loss: 0.013883 	Time: 3.43secs (모델 저장됨)
#
#
# [INFO] Epoch: 352 	Train Loss: 0.205603	Valid Loss: 0.013876 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 353 	Train Loss: 0.205564	Valid Loss: 0.013870 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 354 	Train Loss: 0.205525	Valid Loss: 0.013864 	Time: 3.47secs (모델 저장됨)
#
#
# [INFO] Epoch: 355 	Train Loss: 0.205487	Valid Loss: 0.013858 	Time: 3.60secs (모델 저장됨)
#
#
# [INFO] Epoch: 356 	Train Loss: 0.205449	Valid Loss: 0.013852 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 357 	Train Loss: 0.205411	Valid Loss: 0.013846 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 358 	Train Loss: 0.205372	Valid Loss: 0.013840 	Time: 3.25secs (모델 저장됨)
#
#
# [INFO] Epoch: 359 	Train Loss: 0.205335	Valid Loss: 0.013834 	Time: 3.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 360 	Train Loss: 0.205297	Valid Loss: 0.013828 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 361 	Train Loss: 0.205259	Valid Loss: 0.013822 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 362 	Train Loss: 0.205221	Valid Loss: 0.013816 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 363 	Train Loss: 0.205184	Valid Loss: 0.013810 	Time: 4.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 364 	Train Loss: 0.205146	Valid Loss: 0.013804 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 365 	Train Loss: 0.205109	Valid Loss: 0.013798 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 366 	Train Loss: 0.205072	Valid Loss: 0.013792 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 367 	Train Loss: 0.205035	Valid Loss: 0.013787 	Time: 4.11secs (모델 저장됨)
#
#
# [INFO] Epoch: 368 	Train Loss: 0.204998	Valid Loss: 0.013781 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 369 	Train Loss: 0.204961	Valid Loss: 0.013775 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 370 	Train Loss: 0.204924	Valid Loss: 0.013769 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 371 	Train Loss: 0.204887	Valid Loss: 0.013764 	Time: 3.91secs (모델 저장됨)
#
#
# [INFO] Epoch: 372 	Train Loss: 0.204850	Valid Loss: 0.013758 	Time: 3.14secs (모델 저장됨)
#
#
# [INFO] Epoch: 373 	Train Loss: 0.204814	Valid Loss: 0.013752 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 374 	Train Loss: 0.204777	Valid Loss: 0.013747 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 375 	Train Loss: 0.204741	Valid Loss: 0.013741 	Time: 4.30secs (모델 저장됨)
#
#
# [INFO] Epoch: 376 	Train Loss: 0.204705	Valid Loss: 0.013736 	Time: 3.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 377 	Train Loss: 0.204669	Valid Loss: 0.013730 	Time: 3.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 378 	Train Loss: 0.204633	Valid Loss: 0.013725 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 379 	Train Loss: 0.204597	Valid Loss: 0.013719 	Time: 3.78secs (모델 저장됨)
#
#
# [INFO] Epoch: 380 	Train Loss: 0.204561	Valid Loss: 0.013714 	Time: 3.37secs (모델 저장됨)
#
#
# [INFO] Epoch: 381 	Train Loss: 0.204525	Valid Loss: 0.013708 	Time: 3.08secs (모델 저장됨)
#
#
# [INFO] Epoch: 382 	Train Loss: 0.204489	Valid Loss: 0.013703 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 383 	Train Loss: 0.204454	Valid Loss: 0.013698 	Time: 3.63secs (모델 저장됨)
#
#
# [INFO] Epoch: 384 	Train Loss: 0.204418	Valid Loss: 0.013692 	Time: 3.51secs (모델 저장됨)
#
#
# [INFO] Epoch: 385 	Train Loss: 0.204383	Valid Loss: 0.013687 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 386 	Train Loss: 0.204347	Valid Loss: 0.013682 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 387 	Train Loss: 0.204312	Valid Loss: 0.013676 	Time: 3.42secs (모델 저장됨)
#
#
# [INFO] Epoch: 388 	Train Loss: 0.204277	Valid Loss: 0.013671 	Time: 3.70secs (모델 저장됨)
#
#
# [INFO] Epoch: 389 	Train Loss: 0.204242	Valid Loss: 0.013666 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 390 	Train Loss: 0.204207	Valid Loss: 0.013661 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 391 	Train Loss: 0.204172	Valid Loss: 0.013656 	Time: 3.12secs (모델 저장됨)
#
#
# [INFO] Epoch: 392 	Train Loss: 0.204137	Valid Loss: 0.013651 	Time: 3.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 393 	Train Loss: 0.204102	Valid Loss: 0.013645 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 394 	Train Loss: 0.204068	Valid Loss: 0.013640 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 395 	Train Loss: 0.204033	Valid Loss: 0.013635 	Time: 3.65secs (모델 저장됨)
#
#
# [INFO] Epoch: 396 	Train Loss: 0.203998	Valid Loss: 0.013630 	Time: 3.88secs (모델 저장됨)
#
#
# [INFO] Epoch: 397 	Train Loss: 0.203964	Valid Loss: 0.013625 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 398 	Train Loss: 0.203930	Valid Loss: 0.013620 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 399 	Train Loss: 0.203895	Valid Loss: 0.013615 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 400 	Train Loss: 0.203861	Valid Loss: 0.013610 	Time: 4.08secs (모델 저장됨)
#
#
# [INFO] Epoch: 401 	Train Loss: 0.203827	Valid Loss: 0.013606 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 402 	Train Loss: 0.203793	Valid Loss: 0.013601 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 403 	Train Loss: 0.203759	Valid Loss: 0.013596 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 404 	Train Loss: 0.203725	Valid Loss: 0.013591 	Time: 4.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 405 	Train Loss: 0.203691	Valid Loss: 0.013586 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 406 	Train Loss: 0.203657	Valid Loss: 0.013581 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 407 	Train Loss: 0.203623	Valid Loss: 0.013577 	Time: 2.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 408 	Train Loss: 0.203590	Valid Loss: 0.013572 	Time: 3.74secs (모델 저장됨)
#
#
# [INFO] Epoch: 409 	Train Loss: 0.203556	Valid Loss: 0.013567 	Time: 3.21secs (모델 저장됨)
#
#
# [INFO] Epoch: 410 	Train Loss: 0.203522	Valid Loss: 0.013562 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 411 	Train Loss: 0.203489	Valid Loss: 0.013558 	Time: 2.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 412 	Train Loss: 0.203456	Valid Loss: 0.013553 	Time: 3.54secs (모델 저장됨)
#
#
# [INFO] Epoch: 413 	Train Loss: 0.203422	Valid Loss: 0.013548 	Time: 3.58secs (모델 저장됨)
#
#
# [INFO] Epoch: 414 	Train Loss: 0.203389	Valid Loss: 0.013544 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 415 	Train Loss: 0.203356	Valid Loss: 0.013539 	Time: 2.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 416 	Train Loss: 0.203323	Valid Loss: 0.013535 	Time: 3.46secs (모델 저장됨)
#
#
# [INFO] Epoch: 417 	Train Loss: 0.203289	Valid Loss: 0.013530 	Time: 3.68secs (모델 저장됨)
#
#
# [INFO] Epoch: 418 	Train Loss: 0.203256	Valid Loss: 0.013526 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 419 	Train Loss: 0.203223	Valid Loss: 0.013521 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 420 	Train Loss: 0.203191	Valid Loss: 0.013517 	Time: 3.21secs (모델 저장됨)
#
#
# [INFO] Epoch: 421 	Train Loss: 0.203158	Valid Loss: 0.013512 	Time: 3.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 422 	Train Loss: 0.203125	Valid Loss: 0.013508 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 423 	Train Loss: 0.203092	Valid Loss: 0.013503 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 424 	Train Loss: 0.203059	Valid Loss: 0.013499 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 425 	Train Loss: 0.203027	Valid Loss: 0.013495 	Time: 4.13secs (모델 저장됨)
#
#
# [INFO] Epoch: 426 	Train Loss: 0.202994	Valid Loss: 0.013490 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 427 	Train Loss: 0.202962	Valid Loss: 0.013486 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 428 	Train Loss: 0.202929	Valid Loss: 0.013482 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 429 	Train Loss: 0.202897	Valid Loss: 0.013477 	Time: 4.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 430 	Train Loss: 0.202864	Valid Loss: 0.013473 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 431 	Train Loss: 0.202832	Valid Loss: 0.013469 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 432 	Train Loss: 0.202800	Valid Loss: 0.013465 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 433 	Train Loss: 0.202768	Valid Loss: 0.013461 	Time: 3.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 434 	Train Loss: 0.202735	Valid Loss: 0.013456 	Time: 3.29secs (모델 저장됨)
#
#
# [INFO] Epoch: 435 	Train Loss: 0.202703	Valid Loss: 0.013452 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 436 	Train Loss: 0.202671	Valid Loss: 0.013448 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 437 	Train Loss: 0.202639	Valid Loss: 0.013444 	Time: 3.64secs (모델 저장됨)
#
#
# [INFO] Epoch: 438 	Train Loss: 0.202607	Valid Loss: 0.013440 	Time: 3.41secs (모델 저장됨)
#
#
# [INFO] Epoch: 439 	Train Loss: 0.202575	Valid Loss: 0.013436 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 440 	Train Loss: 0.202543	Valid Loss: 0.013432 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 441 	Train Loss: 0.202511	Valid Loss: 0.013428 	Time: 3.41secs (모델 저장됨)
#
#
# [INFO] Epoch: 442 	Train Loss: 0.202480	Valid Loss: 0.013424 	Time: 3.64secs (모델 저장됨)
#
#
# [INFO] Epoch: 443 	Train Loss: 0.202448	Valid Loss: 0.013420 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 444 	Train Loss: 0.202416	Valid Loss: 0.013416 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 445 	Train Loss: 0.202384	Valid Loss: 0.013412 	Time: 3.18secs (모델 저장됨)
#
#
# [INFO] Epoch: 446 	Train Loss: 0.202353	Valid Loss: 0.013408 	Time: 3.82secs (모델 저장됨)
#
#
# [INFO] Epoch: 447 	Train Loss: 0.202321	Valid Loss: 0.013404 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 448 	Train Loss: 0.202289	Valid Loss: 0.013400 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 449 	Train Loss: 0.202258	Valid Loss: 0.013396 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 450 	Train Loss: 0.202226	Valid Loss: 0.013393 	Time: 4.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 451 	Train Loss: 0.202195	Valid Loss: 0.013389 	Time: 3.07secs (모델 저장됨)
#
#
# [INFO] Epoch: 452 	Train Loss: 0.202163	Valid Loss: 0.013385 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 453 	Train Loss: 0.202132	Valid Loss: 0.013381 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 454 	Train Loss: 0.202100	Valid Loss: 0.013377 	Time: 4.09secs (모델 저장됨)
#
#
# [INFO] Epoch: 455 	Train Loss: 0.202069	Valid Loss: 0.013374 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 456 	Train Loss: 0.202037	Valid Loss: 0.013370 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 457 	Train Loss: 0.202006	Valid Loss: 0.013366 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 458 	Train Loss: 0.201975	Valid Loss: 0.013362 	Time: 3.86secs (모델 저장됨)
#
#
# [INFO] Epoch: 459 	Train Loss: 0.201944	Valid Loss: 0.013359 	Time: 3.24secs (모델 저장됨)
#
#
# [INFO] Epoch: 460 	Train Loss: 0.201912	Valid Loss: 0.013355 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 461 	Train Loss: 0.201881	Valid Loss: 0.013352 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 462 	Train Loss: 0.201850	Valid Loss: 0.013348 	Time: 3.59secs (모델 저장됨)
#
#
# [INFO] Epoch: 463 	Train Loss: 0.201819	Valid Loss: 0.013344 	Time: 3.55secs (모델 저장됨)
#
#
# [INFO] Epoch: 464 	Train Loss: 0.201787	Valid Loss: 0.013341 	Time: 3.01secs (모델 저장됨)
#
#
# [INFO] Epoch: 465 	Train Loss: 0.201756	Valid Loss: 0.013337 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 466 	Train Loss: 0.201725	Valid Loss: 0.013334 	Time: 3.39secs (모델 저장됨)
#
#
# [INFO] Epoch: 467 	Train Loss: 0.201694	Valid Loss: 0.013330 	Time: 3.70secs (모델 저장됨)
#
#
# [INFO] Epoch: 468 	Train Loss: 0.201663	Valid Loss: 0.013327 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 469 	Train Loss: 0.201632	Valid Loss: 0.013323 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 470 	Train Loss: 0.201601	Valid Loss: 0.013320 	Time: 3.24secs (모델 저장됨)
#
#
# [INFO] Epoch: 471 	Train Loss: 0.201570	Valid Loss: 0.013316 	Time: 3.91secs (모델 저장됨)
#
#
# [INFO] Epoch: 472 	Train Loss: 0.201539	Valid Loss: 0.013313 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 473 	Train Loss: 0.201507	Valid Loss: 0.013309 	Time: 3.06secs (모델 저장됨)
#
#
# [INFO] Epoch: 474 	Train Loss: 0.201476	Valid Loss: 0.013306 	Time: 3.03secs (모델 저장됨)
#
#
# [INFO] Epoch: 475 	Train Loss: 0.201445	Valid Loss: 0.013302 	Time: 4.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 476 	Train Loss: 0.201414	Valid Loss: 0.013299 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 477 	Train Loss: 0.201383	Valid Loss: 0.013296 	Time: 3.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 478 	Train Loss: 0.201353	Valid Loss: 0.013292 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 479 	Train Loss: 0.201322	Valid Loss: 0.013289 	Time: 4.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 480 	Train Loss: 0.201291	Valid Loss: 0.013286 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 481 	Train Loss: 0.201260	Valid Loss: 0.013282 	Time: 2.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 482 	Train Loss: 0.201229	Valid Loss: 0.013279 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 483 	Train Loss: 0.201198	Valid Loss: 0.013276 	Time: 3.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 484 	Train Loss: 0.201167	Valid Loss: 0.013272 	Time: 3.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 485 	Train Loss: 0.201136	Valid Loss: 0.013269 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 486 	Train Loss: 0.201105	Valid Loss: 0.013266 	Time: 2.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 487 	Train Loss: 0.201074	Valid Loss: 0.013263 	Time: 3.72secs (모델 저장됨)
#
#
# [INFO] Epoch: 488 	Train Loss: 0.201043	Valid Loss: 0.013259 	Time: 3.31secs (모델 저장됨)
#
#
# [INFO] Epoch: 489 	Train Loss: 0.201013	Valid Loss: 0.013256 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 490 	Train Loss: 0.200982	Valid Loss: 0.013253 	Time: 2.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 491 	Train Loss: 0.200951	Valid Loss: 0.013250 	Time: 3.56secs (모델 저장됨)
#
#
# [INFO] Epoch: 492 	Train Loss: 0.200920	Valid Loss: 0.013247 	Time: 3.58secs (모델 저장됨)
#
#
# [INFO] Epoch: 493 	Train Loss: 0.200889	Valid Loss: 0.013244 	Time: 3.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 494 	Train Loss: 0.200858	Valid Loss: 0.013240 	Time: 2.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 495 	Train Loss: 0.200828	Valid Loss: 0.013237 	Time: 3.32secs (모델 저장됨)
#
#
# [INFO] Epoch: 496 	Train Loss: 0.200797	Valid Loss: 0.013234 	Time: 3.73secs (모델 저장됨)
#
#
# [INFO] Epoch: 497 	Train Loss: 0.200766	Valid Loss: 0.013231 	Time: 3.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 498 	Train Loss: 0.200735	Valid Loss: 0.013228 	Time: 3.05secs (모델 저장됨)
#
#
# [INFO] Epoch: 499 	Train Loss: 0.200704	Valid Loss: 0.013225 	Time: 3.21secs (모델 저장됨)
#
#
# [INFO] Epoch: 500 	Train Loss: 0.200674	Valid Loss: 0.013222 	Time: 3.82secs (모델 저장됨)

# %%
# Load best model # 미리 사전훈련한 가중치를 불러와도됨, 주의할점은 모델은 사전훈련했던 모델과 똑같은 구조여야 가중치를 로드할수있음

# 방금 학습에서 가장 낮은 valid loss를 가졌던 epoch의 가중치를 불러오기
model = LSTM(input_size=1, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)

#model.load_state_dict( torch.load( "./" + args.model_name + ".pth"  ,weights_only=True) )
model.load_state_dict( torch.load( "./" + "LSTM_pretrained.pth" ) )

model.eval()

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %%
# 테스트 데이터 예측
pred = None
with torch.no_grad():
    for data, target in tqdm( test_dl ):
        data   = data.to( device )
        target = target.to( device )
        if pred is None:
            pred = model(data).cpu().numpy()  # 처음 예측 값을 NumPy 배열로 변환
        else:
            pred = np.concatenate([pred, model(data).cpu().numpy()])  # 이후 예측 값들을 연결
# Out:
# 100%|██████████| 269/269 [00:00<00:00, 1124.93it/s]

# %%
# Reshaping
testY_ = testY.squeeze(-1) # 마지막 차원 제거
pred  = pred.squeeze(-1) # 마지막 차원 제거

# %%
testY_.shape
# Out:
# (4294, 7)

# %%
pred.shape
# Out:
# (4294, 7)

# %%
# Inverse scaling
#
for i in range( args.Horizon ):
    testY_[:,  i] = scaler.inverse_transform( testY_[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)

# %%
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]


plt.figure(figsize=(20, 15))

# 랜덤 케이스 선택 (9개만)
RandomInstances = [random.randint(1, testY_.shape[0]) for i in range(0, 9)]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.plot(testDate[i], testY_[i], color='g', marker='o', linewidth=2)
    plt.plot(testDate[i], pred[i], color='r', marker='o', linewidth=2)

    plt.legend(['Real', 'Pred'], fontsize=12)
    plt.ylim([0, 100])
    plt.xticks(rotation=45)
plt.show()

# %%
# 가장 최근 예측

plt.plot(testDate[-1], testY_[-1], color='g', marker='o', linewidth=2)
plt.plot(testDate[-1], pred[-1], color='r', marker='o', linewidth=2)

plt.legend(['Real', 'Pred'], fontsize=12)
plt.ylim([0, 100])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```
#
# ### Multivariate Forecasting

# %%
df = pd.read_csv( args.filename )
df
# Out:
#                       date    supplyT    returnT    volume     energy  \
# 0      2019-08-21 05:00:00  62.552500  41.200000  153128.4  2762320.0
# 1      2019-08-21 06:00:00  62.297143  43.724286  153128.9  2762340.0
# 2      2019-08-21 07:00:00  62.051429  47.042857  153129.4  2762340.0
# 3      2019-08-21 08:00:00  61.840000  45.663750  153129.9  2762360.0
# 4      2019-08-21 09:00:00  62.202857  43.570000  153130.6  2762370.0
# ...                    ...        ...        ...       ...        ...
# 21492  2022-02-01 17:00:00  76.191818  40.070000  173871.3  3384290.0
# 21493  2022-02-01 18:00:00  76.115000  39.591000  173872.5  3384340.0
# 21494  2022-02-01 19:00:00  75.956364  38.787273  173873.7  3384390.0
# 21495  2022-02-01 20:00:00  76.007273  38.352727  173875.0  3384450.0
# 21496  2022-02-01 21:00:00  76.064000  38.667000  173876.3  3384500.0
#
#            flow  Frederikshavn Temperature [2 m elevation corrected]  \
# 0      0.678000                                          12.157285
# 1      0.589714                                          12.517284
# 2      0.510857                                          12.897284
# 3      0.429000                                          13.387284
# 4      0.812571                                          13.897284
# ...         ...                                                ...
# 21492  1.217455                                           5.197285
# 21493  1.279200                                           4.497285
# 21494  1.217455                                           3.987285
# 21495  1.208727                                           3.637285
# 21496  1.293600                                           3.467285
#
#               OT
# 0      16.775000
# 1      12.071429
# 2      10.028571
# 3       8.837500
# 4      20.014286
# ...          ...
# 21492  50.790909
# 21493  53.970000
# 21494  52.209091
# 21495  52.518182
# 21496  55.820000
#
# [21497 rows x 8 columns]

# %%
# 'date' 열이 있다면 datetime 형식으로 변환
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])

# 데이터의 80%를 훈련 데이터로 사용하고 나머지는 테스트 데이터로 사용
idx = int(df.shape[0] * args.TrainingSetPercentage)

df_train = df[:idx].dropna().reset_index(drop=True)
df_test = df[idx:].dropna().reset_index(drop=True)

# %%
# 테스트 데이터의 시작 부분에 훈련 데이터의 마지막 'Lag' 행을 추가
df_test = pd.concat([df_train.iloc[-args.Lag:], df_test]).reset_index(drop=True)

# 스케일링할 피처 목록을 정의 ('date' 제외)
features_to_scale = df.columns.drop(['date'])

# 스케일링 설정
if args.Scaling == 'MinMax':
    print('[INFO] Scaling: MinMax')
    scaler = MinMaxScaler()
elif args.Scaling == 'Robust':
    print('[INFO] Scaling: Robust')
    scaler = RobustScaler()
else:
    print('[INFO] Scaling: Standard')
    scaler = StandardScaler()

# 훈련 데이터에 스케일러를 핏
df_train[features_to_scale] = scaler.fit_transform(df_train[features_to_scale])

# 동일한 스케일러로 테스트 데이터를 변환
df_test[features_to_scale] = scaler.transform(df_test[features_to_scale])
# Out:
# [INFO] Scaling: Standard

# %%
# LSTM 모델을 위한 시퀀스를 생성합니다.
def create_dataset(df, Lag=1, Horizon=1, targetSeries=None, feature_cols=None):
    dataX, dataY, dataDate = [], [], []

    for i in tqdm(range(0, df.shape[0] + 1 - Lag - Horizon)):
        # 입력 시퀀스 X를 선택합니다.
        dataX.append(df[feature_cols].iloc[i:(i + Lag)].to_numpy())
        # 타겟 변수 y를 선택합니다.
        dataY.append(df[targetSeries].iloc[i + Lag : i + Lag + Horizon].to_numpy())
        # 참조를 위한 날짜를 저장합니다.
        dataDate.append(df['date'].iloc[i + Lag : i + Lag + Horizon].tolist())

    return (np.array(dataX), np.array(dataY), np.array(dataDate))

# 피처 컬럼 목록을 정의합니다 ('date' 제외)
feature_cols = df.columns.drop(['date'])

# %%
# 데이터셋을 생성합니다.
trainX, trainY, _ = create_dataset(df=df_train, Lag=args.Lag, Horizon=args.Horizon,
                                   targetSeries=args.targetSeries, feature_cols=feature_cols)

testX, testY, testDate = create_dataset(df=df_test, Lag=args.Lag, Horizon=args.Horizon,
                                        targetSeries=args.targetSeries, feature_cols=feature_cols)
# Out:
# 100%|██████████| 17161/17161 [00:17<00:00, 992.59it/s]
# 100%|██████████| 4294/4294 [00:02<00:00, 1434.16it/s]

# %%
trainX.shape
# Out:
# (17161, 30, 7)

# %%
# 훈련 데이터의 마지막 10%를 검증 데이터로 사용합니다.
idx = int(0.9 * trainX.shape[0])

validX, validY = trainX[idx:], trainY[idx:]
trainX, trainY = trainX[:idx], trainY[:idx]

# 필요에 따라 Y의 차원을 확장합니다.
trainY = np.expand_dims(trainY, axis=-1)
validY = np.expand_dims(validY, axis=-1)
testY = np.expand_dims(testY, axis=-1)

# 데이터셋의 모양을 출력합니다.
print('Training data shape:   ', trainX.shape, trainY.shape)
print('Validation data shape: ', validX.shape, validY.shape)
print('Testing data shape:    ', testX.shape, testY.shape)
# Out:
# Training data shape:    (15444, 30, 7) (15444, 7, 1)
# Validation data shape:  (1717, 30, 7) (1717, 7, 1)
# Testing data shape:     (4294, 30, 7) (4294, 7, 1)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    def __init__(self, X, Y):
        # 데이터를 torch.tensor로 변환하고 데이터 타입을 float32로 설정
        self.X = torch.tensor(X, dtype=torch.float32)
        self.Y = torch.tensor(Y, dtype=torch.float32)
    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# 훈련 및 테스트 데이터로더 생성
#
train_ds = Data(trainX, trainY)
valid_ds = Data(validX, validY)
test_ds  = Data(testX,  testY)

# 데이터 로더 준비
#
train_dl = DataLoader(train_ds, batch_size=args.batch_size, shuffle=True)
valid_dl = DataLoader(valid_ds, batch_size=args.batch_size, shuffle=False)
test_dl  = DataLoader(test_ds,  batch_size=args.batch_size, shuffle=False)

# %%
print(trainX[1,1:30,-1])
print(trainY[1,:,-1])
# Out:
# [-0.9088272  -0.96826401 -0.4105204  -0.78799315 -1.04855271 -0.95641229
#  -0.42691676 -0.92950087 -1.02502749 -0.98154149 -0.54525572 -0.85393503
#  -1.00221517 -0.77239878 -1.14835664 -1.27328979 -1.20467458 -1.14895072
#  -1.20280326 -1.20182304 -0.77979497 -0.84609329 -0.3527767  -0.78692382
#  -0.70191225 -0.89385661 -0.8988468  -1.00381916 -0.89314372]
# [-0.75341821 -1.01575999 -0.98296726 -0.80795393 -0.89279319 -0.64090204
#  -0.83760956]

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, hidden_size=50, num_layers=1, output_length=24):
        """
        LSTM 모델 초기화

        Args:
            input_size (int): 각 시간 단계별 입력 특징 수.
            hidden_size (int): 은닉 상태의 특징 수.
            num_layers (int): 순환 레이어 수.
            output_length (int): 출력 시퀀스 길이.
        """
        super().__init__()
        self.hidden_size = hidden_size
        self.output_length = output_length
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_length)

    def forward(self, x):
        # LSTM 레이어 통과 (초기 은닉 상태와 셀 상태는 기본적으로 0으로 초기화됩니다)
        out, _ = self.lstm(x)  # out: (batch_size, seq_length, hidden_size)
        # 마지막 시점의 출력을 사용하여 완전 연결 레이어 통과
        out = self.fc(out[:, -1, :])  # out: (batch_size, output_length)
        return out.unsqueeze(2)  # 출력 형태: (batch_size, output_length, 1)

# %%
# 피처의 수를 설정합니다 (예: 7개의 피처)
input_size = len(feature_cols)  # feature_cols는 이전에 정의한 피처 목록입니다

# 모델 생성
model = LSTM(input_size=input_size, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)

# DataLoader에서 데이터 가져오기
for data, target in train_dl:
    print(f"Input data shape: {data.shape}")  # 예상 형태: (배치 크기, 시퀀스 길이, 입력 특징 수)
    print(f"Target data shape: {target.shape}")  # 예상 형태: (배치 크기, 출력 길이, 1)
    break

# 손실 함수와 옵티마이저 정의
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(params=model.parameters(), lr=args.learning_rate)

# 조기 종료 및 학습률 스케줄러 설정
early_stopping = EarlyStopping(patience=10, min_delta=1e-5)
scheduler = LRScheduler(optimizer=optimizer, patience=3, min_lr=1e-10, factor=0.5)
# Out:
# Input data shape: torch.Size([16, 30, 7])
# Target data shape: torch.Size([16, 7, 1])

# %%
# 훈련 및 검증 손실 저장
Loss = {'Train': [], 'Valid': []}

# 메인 루프 - 훈련 과정
Best_score = None  # Best_score 초기화
for epoch in range(1, args.epochs+1):
    start = time.time()
    train_loss = 0.0
    valid_loss = 0.0

    ###################
    #     모델 훈련    #
    ###################
    model.train()
    for data, target in train_dl:
        optimizer.zero_grad()
        data = data.to(device)
        target = target.to(device)
        outputs = model(data)
        loss = criterion(outputs, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item() * data.size(0)
    train_loss = train_loss / len(train_dl.dataset)

    ###################
    #   검증 단계     #
    ###################
    model.eval()
    with torch.no_grad():
        for data, target in valid_dl:
            data = data.to(device)
            target = target.to(device)
            outputs = model(data)
            loss = criterion(outputs, target)
            valid_loss += loss.item() * data.size(0)
    valid_loss = valid_loss / len(valid_dl.dataset)

    stop = time.time()
    print(f'\n[INFO] Epoch: {epoch} \tTrain Loss: {train_loss:.6f}\tValid Loss: {valid_loss:.6f} \tTime: {stop - start:.2f} secs', end=' ')

    # 최적 모델 저장
    if epoch == 1 or (Best_score is not None and valid_loss < Best_score):
        Best_score = valid_loss
        torch.save(model.state_dict(), "./" + args.model_name + ".pth")
        print('(모델 저장됨)\n')
    else:
        print('\n')

    # 손실 저장
    Loss['Train'].append(train_loss)
    Loss['Valid'].append(valid_loss)

    # 학습률 스케줄러 업데이트
    scheduler(valid_loss)

    # 조기 종료 체크
    if early_stopping(valid_loss):
        print("[INFO] 조기 종료 조건 만족. 학습을 종료합니다.")
        break
# Out:
# [INFO] Epoch: 1 	Train Loss: 0.451990	Valid Loss: 0.059187 	Time: 3.01 secs (모델 저장됨)
#
#
# [INFO] Epoch: 2 	Train Loss: 0.347498	Valid Loss: 0.072105 	Time: 2.97 secs
#
#
# [INFO] Epoch: 3 	Train Loss: 0.339393	Valid Loss: 0.060295 	Time: 3.01 secs
#
#
# [INFO] Epoch: 4 	Train Loss: 0.333808	Valid Loss: 0.056042 	Time: 4.10 secs (모델 저장됨)
#
#
# [INFO] Epoch: 5 	Train Loss: 0.330237	Valid Loss: 0.051354 	Time: 3.00 secs (모델 저장됨)
#
#
# [INFO] Epoch: 6 	Train Loss: 0.327169	Valid Loss: 0.053065 	Time: 3.01 secs
#
#
# [INFO] Epoch: 7 	Train Loss: 0.324171	Valid Loss: 0.053940 	Time: 2.96 secs
#
#
# [INFO] Epoch: 8 	Train Loss: 0.320639	Valid Loss: 0.060148 	Time: 3.97 secs
#
#
# [INFO] Epoch: 9 	Train Loss: 0.315636	Valid Loss: 0.051133 	Time: 3.11 secs (모델 저장됨)
#
#
# [INFO] Epoch: 10 	Train Loss: 0.304649	Valid Loss: 0.049351 	Time: 3.00 secs (모델 저장됨)
#
#
# [INFO] Epoch: 11 	Train Loss: 0.290234	Valid Loss: 0.063085 	Time: 2.98 secs
#
#
# [INFO] Epoch: 12 	Train Loss: 0.278128	Valid Loss: 0.067931 	Time: 3.74 secs
#
#
# [INFO] Epoch: 13 	Train Loss: 0.265466	Valid Loss: 0.056937 	Time: 3.32 secs
#
#
# [INFO] Epoch: 14 	Train Loss: 0.252944	Valid Loss: 0.074527 	Time: 3.00 secs
#
#
# [INFO] Epoch: 15 	Train Loss: 0.241688	Valid Loss: 0.076391 	Time: 3.01 secs
#
#
# [INFO] Epoch: 16 	Train Loss: 0.236295	Valid Loss: 0.061026 	Time: 3.55 secs
#
#
# [INFO] Epoch: 17 	Train Loss: 0.232012	Valid Loss: 0.060858 	Time: 3.49 secs
#
#
# [INFO] Epoch: 18 	Train Loss: 0.228535	Valid Loss: 0.056722 	Time: 2.96 secs
#
#
# [INFO] Epoch: 19 	Train Loss: 0.225020	Valid Loss: 0.061680 	Time: 2.97 secs
#
#
# [INFO] Epoch: 20 	Train Loss: 0.223507	Valid Loss: 0.060806 	Time: 3.31 secs
#
# [INFO] Early stopping
# [INFO] 조기 종료 조건 만족. 학습을 종료합니다.

# %%
# 최적 모델 로드
model.load_state_dict(torch.load("./" + args.model_name + ".pth"))
model.eval()
print('[INFO] 최적 모델이 로드되었습니다.')
# Out:
# [INFO] 최적 모델이 로드되었습니다.

# %%
import numpy as np
import torch

# 테스트 데이터 예측
test_predictions = []
test_targets = []
with torch.no_grad():
    for data, target in tqdm(test_dl):
        data = data.to(device)
        target = target.to(device)
        output = model(data)
        test_predictions.append(output.cpu().numpy())
        test_targets.append(target.cpu().numpy())

# 예측값과 실제값을 배열로 연결
test_predictions = np.concatenate(test_predictions, axis=0)
test_targets = np.concatenate(test_targets, axis=0)

# 출력 형태 확인
print(f"Predictions shape: {test_predictions.shape}")
print(f"Targets shape: {test_targets.shape}")

# 필요한 경우 출력 차원 조정
test_predictions = test_predictions.reshape(-1, args.Horizon)
test_targets = test_targets.reshape(-1, args.Horizon)
# Out:
# 100%|██████████| 269/269 [00:00<00:00, 871.93it/s]
# Predictions shape: (4294, 7, 1)
# Targets shape: (4294, 7, 1)

# %%
# 피처의 수와 대상 변수의 인덱스 찾기
num_features = len(feature_cols)
feature_cols_list = list(feature_cols)
target_index = feature_cols_list.index(args.targetSeries)

# 예측값과 실제값을 평탄화
n_samples = test_predictions.shape[0]
test_predictions_flat = test_predictions.flatten().reshape(-1, 1)
test_targets_flat = test_targets.flatten().reshape(-1, 1)

# 역스케일링을 위한 배열 생성
pred_full = np.zeros((n_samples * args.Horizon, num_features))
target_full = np.zeros((n_samples * args.Horizon, num_features))

# 대상 변수 위치에 예측값과 실제값을 삽입
pred_full[:, target_index] = test_predictions_flat.squeeze()
target_full[:, target_index] = test_targets_flat.squeeze()

# 역스케일링 수행
pred_inv_flat = scaler.inverse_transform(pred_full)[:, target_index]
target_inv_flat = scaler.inverse_transform(target_full)[:, target_index]

# 원래 형태로 재조정
test_predictions_inv = pred_inv_flat.reshape(n_samples, args.Horizon)
test_targets_inv = target_inv_flat.reshape(n_samples, args.Horizon)

# %%
import matplotlib.pyplot as plt
import random

# 서브플롯 설정
subplots = [331, 332, 333, 334, 335, 336,  337, 338, 339]

plt.figure(figsize=(20, 15))

# 랜덤 케이스 선택 (9개만)
RandomInstances = [random.randint(0, n_samples - 1) for _ in range(9)]

for plot_id, i in enumerate(RandomInstances):

    plt.subplot(subplots[plot_id])
    plt.plot(testDate[i], test_targets_inv[i], color='g', marker='o', linewidth=2)
    plt.plot(testDate[i], test_predictions_inv[i], color='r', marker='o', linewidth=2)

    plt.legend(['Real', 'Pred'], fontsize=12)
    plt.ylim([min(test_targets_inv.min(), test_predictions_inv.min()) - 10,
              max(test_targets_inv.max(), test_predictions_inv.max()) + 10])
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# 가장 최근 예측

plt.figure(figsize=(10, 5))
plt.plot(testDate[-1], test_targets_inv[-1], color='g', marker='o', linewidth=2)
plt.plot(testDate[-1], test_predictions_inv[-1], color='r', marker='o', linewidth=2)

plt.legend(['Real', 'Pred'], fontsize=12)
plt.ylim([min(test_targets_inv[-1].min(), test_predictions_inv[-1].min()) - 10,
          max(test_targets_inv[-1].max(), test_predictions_inv[-1].max()) + 10])
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
