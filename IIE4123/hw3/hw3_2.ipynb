# %% [markdown]
# #### 1) 데이터 불러오기

# %%
import torch
import warnings
import time
import random
import pandas    as pd
import numpy     as np
from   tqdm      import tqdm
import matplotlib.pyplot   as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
import torch
import torch.nn                     as nn
import torch.nn.functional          as F
from   torch.utils.data             import Dataset,DataLoader


# 시드(seed) 고정
random_seed = 42
torch.manual_seed(random_seed)
np.random.seed(random_seed)
random.seed(random_seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
warnings.filterwarnings(action='ignore')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cpu

# %%
# 데이터 파일 경로 설정
df = pd.read_csv('C:/Users/symply_jina/Desktop/seohyun/IIE4123/hw3/LSTM_practice/electricity.csv')

# %%
# 하이퍼 파라미터 설정
class Parameters():
    def __init__(self):
        self.description = 'LSTM 모델을 이용한 시계열 예측'
        # 입력 시퀀스 길이 - look-back
        self.Lag         = 30
        # 예측 시퀀스 길이
        self.Horizon     = 7

        # 에포크 수
        self.epochs        = 500
        # 배치 크기
        self.batch_size    = 16
        # 학습률
        self.learning_rate = 1e-4 # 0.0001
        # 훈련된 모델 경로
        self.model_name    = 'LSTM'
        # 파일명
        self.filename              = './LSTM_practice/electricity.csv'
        # 대상 시계열 이름
        self.targetSeries          = 'OT'
        # 훈련 세트 비율
        self.TrainingSetPercentage = 0.8
        # 스케일링 {'Standard', 'MinMax', 'Robust'}
        self.Scaling               = 'Standard'


args = Parameters()

# %%
df
# Out:
#                       date    supplyT    returnT    volume     energy  \
# 0      2019-08-21 05:00:00  62.552500  41.200000  153128.4  2762320.0
# 1      2019-08-21 06:00:00  62.297143  43.724286  153128.9  2762340.0
# 2      2019-08-21 07:00:00  62.051429  47.042857  153129.4  2762340.0
# 3      2019-08-21 08:00:00  61.840000  45.663750  153129.9  2762360.0
# 4      2019-08-21 09:00:00  62.202857  43.570000  153130.6  2762370.0
# ...                    ...        ...        ...       ...        ...
# 21492  2022-02-01 17:00:00  76.191818  40.070000  173871.3  3384290.0
# 21493  2022-02-01 18:00:00  76.115000  39.591000  173872.5  3384340.0
# 21494  2022-02-01 19:00:00  75.956364  38.787273  173873.7  3384390.0
# 21495  2022-02-01 20:00:00  76.007273  38.352727  173875.0  3384450.0
# 21496  2022-02-01 21:00:00  76.064000  38.667000  173876.3  3384500.0
#
#            flow  Frederikshavn Temperature [2 m elevation corrected]  \
# 0      0.678000                                          12.157285
# 1      0.589714                                          12.517284
# 2      0.510857                                          12.897284
# 3      0.429000                                          13.387284
# 4      0.812571                                          13.897284
# ...         ...                                                ...
# 21492  1.217455                                           5.197285
# 21493  1.279200                                           4.497285
# 21494  1.217455                                           3.987285
# 21495  1.208727                                           3.637285
# 21496  1.293600                                           3.467285
#
#               OT
# 0      16.775000
# 1      12.071429
# 2      10.028571
# 3       8.837500
# 4      20.014286
# ...          ...
# 21492  50.790909
# 21493  53.970000
# 21494  52.209091
# 21495  52.518182
# 21496  55.820000
#
# [21497 rows x 8 columns]

# %% [markdown]
# ### Univariate Forecasting

# %%
# 날짜로 인식하게 수정 후 데이터프레임으로 변환
df['date'] = df['date'].astype('datetime64[ns]')
df.set_index('date', inplace=True)
df = pd.DataFrame( df[ [ args.targetSeries ] ] )
df
# Out:
#                             OT
# date
# 2019-08-21 05:00:00  16.775000
# 2019-08-21 06:00:00  12.071429
# 2019-08-21 07:00:00  10.028571
# 2019-08-21 08:00:00   8.837500
# 2019-08-21 09:00:00  20.014286
# ...                        ...
# 2022-02-01 17:00:00  50.790909
# 2022-02-01 18:00:00  53.970000
# 2022-02-01 19:00:00  52.209091
# 2022-02-01 20:00:00  52.518182
# 2022-02-01 21:00:00  55.820000
#
# [21497 rows x 1 columns]

# %%
# 80% 훈련 나머지 테스트
idx = int( df.shape[0] * args.TrainingSetPercentage )

df_train = df[ :idx ].dropna()
df_test  = df[ idx: ].dropna()

# %%
# 학습 및 테스트 데이터 시각화
fig, ax = plt.subplots(nrows = 1, ncols = 1, figsize=(20, 3) )

df_train.plot(ax=ax, color='tab:blue' )
df_test.plot(ax=ax,  color='tab:orange')

plt.legend(['Training', 'Testing'], fontsize = 14)
plt.ylabel(args.targetSeries, size = 14);
plt.xlabel('Date', size = 14);

# %%
# 테스트 시작시 앞의 과거기간이 필요하므로
# train data의 마지막 날짜로부터 args.Lag 만큼의 데이터를 가져와서 test 앞에 붙임
df_test = pd.concat([df_train.iloc[-args.Lag:], df_test])

# %%
if (args.Scaling == 'MinMax'):
    print('[INFO] Scaling: MinMax')

    scaler = MinMaxScaler()
    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))

elif (args.Scaling == 'Robust'):
    print('[INFO] Scaling: Robust')


    scaler = RobustScaler()
    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))

elif (args.Scaling == 'Standard'):
    print('[INFO] Scaling: Standard')

    scaler = StandardScaler()

    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))
else:
    print('[WARNING] Unknown data scaling. Standard scaling was selected')

    scaler = StandardScaler()

    df_train[args.targetSeries] = scaler.fit_transform(df_train[args.targetSeries].to_numpy().reshape(-1, 1))
    df_test[args.targetSeries]  = scaler.transform(df_test[args.targetSeries].to_numpy().reshape(-1, 1))
# Out:
# [INFO] Scaling: Standard

# %%
def create_dataset(df=None, Lag=1, Horizon=1, targetSeries=None):

    dataX, dataY, dataDate = [], [], []

    # 데이터셋을 생성하기 위한 루프, 0에서 시작해서 데이터프레임의 길이 - Lag - Horizon까지 반복
    for i in tqdm(range(0, df.shape[0] + 1 - Lag - Horizon)):
        # 입력 시퀀스를 dataX에 추가
        dataX.append(df.to_numpy()[i:(i + Lag)])
        # 타겟 시퀀스를 dataY에 추가
        dataY.append(df[targetSeries].to_numpy()[i + Lag : i + Lag + Horizon])
        # 타겟 시퀀스의 날짜를 dataDate에 추가
        dataDate.append(df.index[i + Lag : i + Lag + Horizon].tolist())

    # numpy 배열로 변환하여 반환
    return (np.array(dataX), np.array(dataY), np.array(dataDate))

# %%
print(args.Lag, args.Horizon)
# Out:
# 30 7

# %%
trainX, trainY, _ = create_dataset(df           = df_train,
                                   Lag          = args.Lag,
                                   Horizon      = args.Horizon,
                                   targetSeries = args.targetSeries)


testX,  testY, testDate  = create_dataset(df           = df_test,
                                          Lag          = args.Lag,
                                          Horizon      = args.Horizon,
                                          targetSeries = args.targetSeries)
# Out:
# 100%|██████████| 17161/17161 [00:00<00:00, 64702.00it/s]
# 100%|██████████| 4294/4294 [00:00<00:00, 37333.17it/s]

# %%
# 훈련 데이터의 마지막 10%를 검증용으로 사용
#
# 훈련 데이터에서 검증 데이터로 나누는 인덱스를 계산
idx = int(0.9 * trainX.shape[0])

# 검증 데이터셋을 생성 (마지막 10%)
validX, validY = trainX[idx:], trainY[idx:]

# 훈련 데이터셋을 생성 (처음 90%)
trainX, trainY = trainX[:idx], trainY[:idx]
trainY = np.expand_dims(trainY, axis = -1)
validY = np.expand_dims(validY, axis = -1)
testY  = np.expand_dims(testY,  axis = -1)

# 훈련 데이터셋의 형태 출력
print('Training data shape:   ', trainX.shape, trainY.shape)
# 검증 데이터셋의 형태 출력
print('Validation data shape: ', validX.shape, validY.shape)
# 테스트 데이터셋의 형태 출력
print('Testing data shape:    ', testX.shape,  testY.shape)
# Out:
# Training data shape:    (15444, 30, 1) (15444, 7, 1)
# Validation data shape:  (1717, 30, 1) (1717, 7, 1)
# Testing data shape:     (4294, 30, 1) (4294, 7, 1)

# %%
import torch
from torch.utils.data import Dataset, DataLoader

class Data(Dataset):
    def __init__(self, X, Y):
        # 데이터를 torch.tensor로 변환하고 데이터 타입을 float32로 설정
        self.X = torch.tensor(X, dtype=torch.float32)
        self.Y = torch.tensor(Y, dtype=torch.float32)
    def __len__(self):
        return len(self.Y)

    def __getitem__(self, idx):
        return self.X[idx], self.Y[idx]

# 훈련 및 테스트 데이터로더 생성
#
train_ds = Data(trainX, trainY)
valid_ds = Data(validX, validY)
test_ds  = Data(testX,  testY)

# 데이터 로더 준비
#
train_dl = DataLoader(train_ds, batch_size=args.batch_size, shuffle=False)
valid_dl = DataLoader(valid_ds, batch_size=args.batch_size, shuffle=False)
test_dl  = DataLoader(test_ds,  batch_size=args.batch_size, shuffle=False)

# %% [markdown]
# #### 2) LSTM

# %%
import torch.nn as nn
import torch

class LSTM(nn.Module):
    def __init__(self, input_size=1, hidden_size=50, num_layers=1, output_length=24):
        """
        LSTM 모델 초기화

        Args:
            input_size (int): 각 시간 단계별 입력 특징 수. 단일 채널의 경우 1.
            hidden_size (int): 은닉 상태의 특징 수.
            num_layers (int): 순환 레이어 수.
            output_length (int): 출력 시퀀스 길이.
        """
        super().__init__()
        self.hidden_size = hidden_size
        self.output_length = output_length
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)  # batch_first=True: (batch_size, seq_len, input_size) 형태의 입력
        self.fc = nn.Linear(hidden_size, output_length)  # 최종 출력

    def forward(self, x):

        # 초기 은닉 상태 (h0) 및 셀 상태 (c0)를 0으로 초기화
        h0 = torch.zeros(self.lstm.num_layers, x.size(0), self.hidden_size).to(device)
        c0 = torch.zeros(self.lstm.num_layers, x.size(0), self.hidden_size).to(device)

        # LSTM
        out, _ = self.lstm(x, (h0, c0))  # out: (batch_size, 입력길이, hidden_size)


       # 마지막 시간 단계의 h만 추출하여 fc 통과
        out = self.fc(out[:, -1, :])  # out: (batch_size, output_length)

        return out.unsqueeze(2)  # out: (batch_size, output_length, 1) 형태로 변환

# %%
# 모델 생성해서 데이터 넣어보기
model = LSTM(input_size=1, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)


# 랜덤 입력값 생성 (예: 배치 크기 32, 입력 길이)
input_data = torch.randn(32, args.Lag, 1).to(device)

# 모델 실행 및 출력 확인
output = model(input_data)
print(f"Output shape: {output.shape}")  # (32, 입력 길이, 1) 형태의 출력
# Out:
# Output shape: torch.Size([32, 7, 1])

# %% [markdown]
# #### 3) 학습

# %%
from EarlyStopping      import *
from LRScheduler        import *


model = LSTM(input_size=1, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)

criterion = nn.MSELoss()

optimizer = torch.optim.Adam(params = model.parameters(),
                             lr     = args.learning_rate)


early_stopping = EarlyStopping(patience  = 10,
                               min_delta = 1e-5)


scheduler = LRScheduler(optimizer = optimizer,
                        patience  = 3,
                        min_lr    = 1e-10,
                        factor    = 0.5)

# %%
# 훈련 및 검증 손실 저장
Loss = {
         'Train': [],
         'Valid':  []
       }

# 메인 루프 - 훈련 과정
for epoch in range(1, args.epochs+1):

    # 타이머 시작
    start = time.time()

    # 훈련 손실 모니터링
    train_loss = 0.0
    valid_loss  = 0.0

    ###################
    # 모델 훈련하기 #
    ###################

    for data, target in train_dl:

        #  기울기 초기화
        optimizer.zero_grad()

        data   = data.to(device)
        target = target.to(device)

        outputs = model(data)
        outputs = outputs
        # 손실 계산

        loss = criterion(outputs, target)

        # 기울기 계산
        loss.backward()

        # 업데이트
        optimizer.step()

        train_loss += loss.item() * data.size(0)


    train_loss = train_loss / train_dl.dataset.X.shape[0]

    with torch.no_grad():
        for data, target in valid_dl:

            data   = data.to(device)
            target = target.to(device)

            outputs = model(data)

            # 손실 계산
            loss = criterion(outputs, target)

            # 실행 중인 검증 손실 업데이트
            valid_loss += loss.item() * data.size(0)

    # 평균 훈련 통계 출력
    valid_loss = valid_loss / test_dl.dataset.X.shape[0]

    # 타이머 정지
    stop = time.time()

    # 훈련 결과 출력
    print('\n[INFO] Epoch: {} \tTrain Loss: {:.6f}\tValid Loss: {:.6f} \tTime: {:.2f}secs'.format(epoch, train_loss, valid_loss, stop-start), end=' ')

    # 최적 모델 업데이트
    if (epoch == 1):
        Best_score = valid_loss

        torch.save(model.state_dict(), "./" + args.model_name + ".pth")
        print('(모델 저장됨)\n')
    else:
        if (Best_score > valid_loss):
            Best_score = valid_loss

            torch.save(model.state_dict(), "./" + args.model_name + ".pth")
            print('(모델 저장됨)\n')
        else:
            print('\n')

    # 훈련/검증 손실 저장
    Loss['Train'] += [train_loss]
    Loss['Valid'] += [valid_loss]

    # 학습률 스케줄러
    scheduler(valid_loss)

    # 조기 종료
    if (early_stopping(valid_loss)):
        break
# Out:
# [INFO] Epoch: 1 	Train Loss: 0.604200	Valid Loss: 0.105238 	Time: 13.97secs (모델 저장됨)
#
#
# [INFO] Epoch: 2 	Train Loss: 0.402146	Valid Loss: 0.070028 	Time: 13.98secs (모델 저장됨)
#
#
# [INFO] Epoch:
96secs (모델 저장됨)
#
#
# [INFO] Epoch: 186 	Train Loss: 0.198115	Valid Loss: 0.017586 	Time: 13.68secs (모델 저장됨)
#
#
# [INFO] Epoch: 187 	Train Loss: 0.197983	Valid Loss: 0.017552 	Time: 13.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 188 	Train Loss: 0.197852	Valid Loss: 0.017518 	Time: 13.90secs (모델 저장됨)
#
#
# [INFO] Epoch: 189 	Train Loss: 0.197720	Valid Loss: 0.017484 	Time: 13.81secs (모델 저장됨)
#
#
# [INFO] Epoch: 190 	Train Loss: 0.197589	Valid Loss: 0.017448 	Time: 13.77secs (모델 저장됨)
#
#
# [INFO] Epoch: 191 	Train Loss: 0.197458	Valid Loss: 0.017412 	Time: 13.92secs (모델 저장됨)
#
#
# [INFO] Epoch: 192 	Train Loss: 0.197326	Valid Loss: 0.017375 	Time: 13.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 193 	Train Loss: 0.197190	Valid Loss: 0.017339 	Time: 13.85secs (모델 저장됨)
#
#
# [INFO] Epoch: 194 	Train Loss: 0.197050	Valid Loss: 0.017303 	Time: 13.78secs (모델 저장됨)
#
#
# [INFO] Epoch: 195 	Train Loss: 0.196908	Valid Loss: 0.017270 	Time: 13.76secs (모델 저장됨)
#
#
# [INFO] Epoch: 196 	Train Loss: 0.196765	Valid Loss: 0.017236 	Time: 13.76secs (모델 저장됨)
#
#
# [INFO] Epoch: 197 	Train Loss: 0.196620	Valid Loss: 0.017202 	Time: 13.86secs (모델 저장됨)
#
#
# [INFO] Epoch: 198 	Train Loss: 0.196475	Valid Loss: 0.017171 	Time: 13.79secs (모델 저장됨)
#
#
# [INFO] Epoch: 199 	Train Loss: 0.196330	Valid Loss: 0.017140 	Time: 13.75secs (모델 저장됨)
#
#
# [INFO] Epoch: 200 	Train Loss: 0.196185	Valid Loss: 0.017111 	Time: 13.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 201 	Train Loss: 0.196040	Valid Loss: 0.017084 	Time: 13.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 202 	Train Loss: 0.195898	Valid Loss: 0.017058 	Time: 13.84secs (모델 저장됨)
#
#
# [INFO] Epoch: 203 	Train Loss: 0.195760	Valid Loss: 0.017032 	Time: 13.68secs (모델 저장됨)
#
#
# [INFO] Epoch: 204 	Train Loss: 0.195625	Valid Loss: 0.017006 	Time: 13.92secs (모델 저장됨)
#
#
# [INFO] Epoch: 205 	Train Loss: 0.195493	Valid Loss: 0.016979 	Time: 14.10secs (모델 저장됨)
#
#
# [INFO] Epoch: 206 	Train Loss: 0.195363	Valid Loss: 0.016950 	Time: 14.04secs (모델 저장됨)
#
#
# [INFO] Epoch: 207 	Train Loss: 0.195233	Valid Loss: 0.016920 	Time: 13.92secs (모델 저장됨)
#
#
# [INFO] Epoch: 208 	Train Loss: 0.195099	Valid Loss: 0.016891 	Time: 13.77secs (모델 저장됨)
#
#
# [INFO] Epoch: 209 	Train Loss: 0.194959	Valid Loss: 0.016863 	Time: 13.80secs (모델 저장됨)
#
#
# [INFO] Epoch: 210 	Train Loss: 0.194829	Valid Loss: 0.016834 	Time: 13.88secs (모델 저장됨)
#
#
# [INFO] Epoch: 211 	Train Loss: 0.194711	Valid Loss: 0.016803 	Time: 13.81secs (모델 저장됨)
#
#
# [INFO] Epoch: 212 	Train Loss: 0.194702	Valid Loss: 0.016741 	Time: 13.74secs (모델 저장됨)
#
#
# [INFO] Epoch: 213 	Train Loss: 0.194503	Valid Loss: 0.016758 	Time: 13.74secs
#
#
# [INFO] Epoch: 214 	Train Loss: 0.194879	Valid Loss: 0.016674 	Time: 13.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 215 	Train Loss: 0.194567	Valid Loss: 0.016885 	Time: 13.93secs
#
#
# [INFO] Epoch: 216 	Train Loss: 0.194428	Valid Loss: 0.016793 	Time: 13.95secs
#
#
# [INFO] Epoch: 217 	Train Loss: 0.194456	Valid Loss: 0.016673 	Time: 13.84secs (모델 저장됨)
#
#
# [INFO] Epoch: 218 	Train Loss: 0.194172	Valid Loss: 0.016762 	Time: 13.73secs
#
#
# [INFO] Epoch: 219 	Train Loss: 0.194134	Valid Loss: 0.014496 	Time: 13.61secs (모델 저장됨)
#
#
# [INFO] Epoch: 220 	Train Loss: 0.193554	Valid Loss: 0.014108 	Time: 13.72secs (모델 저장됨)
#
#
# [INFO] Epoch: 221 	Train Loss: 0.193232	Valid Loss: 0.013919 	Time: 13.79secs (모델 저장됨)
#
#
# [INFO] Epoch: 222 	Train Loss: 0.193054	Valid Loss: 0.013823 	Time: 13.91secs (모델 저장됨)
#
#
# [INFO] Epoch: 223 	Train Loss: 0.192927	Valid Loss: 0.013759 	Time: 13.86secs (모델 저장됨)
#
#
# [INFO] Epoch: 224 	Train Loss: 0.192807	Valid Loss: 0.013715 	Time: 13.88secs (모델 저장됨)
#
#
# [INFO] Epoch: 225 	Train Loss: 0.192691	Valid Loss: 0.013681 	Time: 13.99secs (모델 저장됨)
#
#
# [INFO] Epoch: 226 	Train Loss: 0.192582	Valid Loss: 0.013654 	Time: 13.80secs (모델 저장됨)
#
#
# [INFO] Epoch: 227 	Train Loss: 0.192480	Valid Loss: 0.013632 	Time: 13.73secs (모델 저장됨)
#
#
# [INFO] Epoch: 228 	Train Loss: 0.192382	Valid Loss: 0.013614 	Time: 13.85secs (모델 저장됨)
#
#
# [INFO] Epoch: 229 	Train Loss: 0.192286	Valid Loss: 0.013599 	Time: 13.89secs (모델 저장됨)
#
#
# [INFO] Epoch: 230 	Train Loss: 0.192192	Valid Loss: 0.013585 	Time: 13.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 231 	Train Loss: 0.192101	Valid Loss: 0.013574 	Time: 13.86secs (모델 저장됨)
#
#
# [INFO] Epoch: 232 	Train Loss: 0.192011	Valid Loss: 0.013563 	Time: 14.00secs (모델 저장됨)
#
#
# [INFO] Epoch: 233 	Train Loss: 0.191923	Valid Loss: 0.013554 	Time: 14.02secs (모델 저장됨)
#
#
# [INFO] Epoch: 234 	Train Loss: 0.191836	Valid Loss: 0.013546 	Time: 13.96secs (모델 저장됨)
#
#
# [INFO] Epoch: 235 	Train Loss: 0.191751	Valid Loss: 0.013538 	Time: 13.78secs (모델 저장됨)
#
#
# [INFO] Epoch: 236 	Train Loss: 0.191666	Valid Loss: 0.013531 	Time: 13.78secs (모델 저장됨)
#
#
# [INFO] Epoch: 237 	Train Loss: 0.191583	Valid Loss: 0.013525 	Time: 13.66secs (모델 저장됨)
#
#
# [INFO] Epoch: 238 	Train Loss: 0.191500	Valid Loss: 0.013519 	Time: 13.91secs (모델 저장됨)
#
#
# [INFO] Epoch: 239 	Train Loss: 0.191417	Valid Loss: 0.013514 	Time: 13.61secs (모델 저장됨)
#
#
# [INFO] Epoch: 240 	Train Loss: 0.191336	Valid Loss: 0.013509 	Time: 13.90secs (모델 저장됨)
#
#
# [INFO] Epoch: 241 	Train Loss: 0.191255	Valid Loss: 0.013505 	Time: 13.93secs (모델 저장됨)
#
#
# [INFO] Epoch: 242 	Train Loss: 0.191174	Valid Loss: 0.013501 	Time: 13.90secs (모델 저장됨)
#
#
# [INFO] Epoch: 243 	Train Loss: 0.191094	Valid Loss: 0.013497 	Time: 13.90secs (모델 저장됨)
#
#
# [INFO] Epoch: 244 	Train Loss: 0.191014	Valid Loss: 0.013493 	Time: 13.80secs (모델 저장됨)
#
#
# [INFO] Epoch: 245 	Train Loss: 0.190935	Valid Loss: 0.013490 	Time: 13.86secs (모델 저장됨)
#
#
# [INFO] Epoch: 246 	Train Loss: 0.190856	Valid Loss: 0.013487 	Time: 13.76secs (모델 저장됨)
#
#
# [INFO] Epoch: 247 	Train Loss: 0.190777	Valid Loss: 0.013485 	Time: 13.73secs (모델 저장됨)
#
#
# [INFO] Epoch: 248 	Train Loss: 0.190698	Valid Loss: 0.013482 	Time: 13.78secs (모델 저장됨)
#
#
# [INFO] Epoch: 249 	Train Loss: 0.190620	Valid Loss: 0.013480 	Time: 13.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 250 	Train Loss: 0.190542	Valid Loss: 0.013478 	Time: 13.92secs (모델 저장됨)
#
#
# [INFO] Epoch: 251 	Train Loss: 0.190464	Valid Loss: 0.013476 	Time: 13.81secs (모델 저장됨)
#
#
# [INFO] Epoch: 252 	Train Loss: 0.190386	Valid Loss: 0.013474 	Time: 13.71secs (모델 저장됨)
#
#
# [INFO] Epoch: 253 	Train Loss: 0.190309	Valid Loss: 0.013473 	Time: 13.81secs (모델 저장됨)
#
#
# [INFO] Epoch: 254 	Train Loss: 0.190231	Valid Loss: 0.013471 	Time: 13.94secs (모델 저장됨)
#
#
# [INFO] Epoch: 255 	Train Loss: 0.190154	Valid Loss: 0.013470 	Time: 13.95secs (모델 저장됨)
#
#
# [INFO] Epoch: 256 	Train Loss: 0.190077	Valid Loss: 0.013469 	Time: 13.83secs (모델 저장됨)
#
#
# [INFO] Epoch: 257 	Train Loss: 0.190000	Valid Loss: 0.013468 	Time: 13.79secs (모델 저장됨)
#
#
# [INFO] Epoch: 258 	Train Loss: 0.189923	Valid Loss: 0.013467 	Time: 13.98secs (모델 저장됨)
#
#
# [INFO] Epoch: 259 	Train Loss: 0.189847	Valid Loss: 0.013466 	Time: 13.92secs (모델 저장됨)
#
#
# [INFO] Epoch: 260 	Train Loss: 0.189770	Valid Loss: 0.013466 	Time: 13.80secs (모델 저장됨)
#
#
# [INFO] Epoch: 261 	Train Loss: 0.189694	Valid Loss: 0.013465 	Time: 13.82secs (모델 저장됨)
#
#
# [INFO] Epoch: 262 	Train Loss: 0.189618	Valid Loss: 0.013465 	Time: 13.81secs (모델 저장됨)
#
# [INFO] Early stopping

# %%
# Load best model # 미리 사전훈련한 가중치를 불러와도됨, 주의할점은 모델은 사전훈련했던 모델과 똑같은 구조여야 가중치를 로드할수있음

# 방금 학습에서 가장 낮은 valid loss를 가졌던 epoch의 가중치를 불러오기
model = LSTM(input_size=1, hidden_size=50, num_layers=3, output_length=args.Horizon).to(device)

#model.load_state_dict( torch.load( "./" + args.model_name + ".pth"  ,weights_only=True) )
model.load_state_dict( torch.load( "C:/Users/symply_jina/Desktop/seohyun/IIE4123/hw3/LSTM_practice/" + "LSTM_pretrained.pth", map_location=torch.device('cpu') ) )

model.eval()

print('[INFO] Model loaded')
# Out:
# [INFO] Model loaded

# %%
# 테스트 데이터 예측
pred = None
with torch.no_grad():
    for data, target in tqdm( test_dl ):
        data   = data.to( device )
        target = target.to( device )
        if pred is None:
            pred = model(data).cpu().numpy()  # 처음 예측 값을 NumPy 배열로 변환
        else:
            pred = np.concatenate([pred, model(data).cpu().numpy()])  # 이후 예측 값들을 연결
# Out:
# 100%|██████████| 269/269 [00:01<00:00, 202.55it/s]

# %%
# Reshaping
testY_ = testY.squeeze(-1) # 마지막 차원 제거
pred  = pred.squeeze(-1) # 마지막 차원 제거

# %%
testY_.shape
# Out:
# (4294, 7)

# %%
pred.shape
# Out:
# (4294, 7)

# %%
# Inverse scaling

for i in range( args.Horizon ):
    testY_[:,  i] = scaler.inverse_transform( testY_[:,  i].reshape(-1,1) ).squeeze(-1)
    pred[:, i]   = scaler.inverse_transform( pred[:, i].reshape(-1,1) ).squeeze(-1)

# %%
# 전체 테스트 데이터에 대한 예측과 실제값 비교
plt.figure(figsize=(15, 8))

plt.plot(range(len(testY_)), testY_[:, 0], color='skyblue', label='Real', linewidth=2)
plt.plot(range(len(pred)), pred[:, 0], color='blue', label='Predicted', linewidth=2)

plt.title('OT Prediction using OT Time Series Trend', fontsize=15)
plt.xlabel('Test Data Sequence', fontsize=12)
plt.ylabel('OT Value', fontsize=12)
plt.legend(fontsize=12)
plt.grid(True)
plt.show()

# %%
# 테스트 데이터의 MAE 계산
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(testY_, pred)
print(f'테스트 데이터의 Mean Absolute Error (MAE): {mae:.4f}')
# Out:
# 테스트 데이터의 Mean Absolute Error (MAE): 5.7369

# %%
# 실제 값과 예측 값의 산점도 그리기
plt.figure(figsize=(10, 8))
plt.scatter(testY_, pred, alpha=0.5)
plt.plot([0, 100], [0, 100], 'r--')  # 이상적인 예측선 (y=x)

plt.xlabel('Real OT', fontsize=12)
plt.ylabel('Predicted OT', fontsize=12)
plt.title('Real OT vs Predicted OT _ Scatter Plot', fontsize=15)

plt.grid(True)
plt.show()
